# %%
import nibabel as nib
import numpy as np
from functions import search_circles, find_lines, process_central_lines, process_b_spline_central_lines, visualize_lines
from skimage import morphology, measure
import open3d as o3d

# 文件路径
#nifti_file = 'Cshape/5475-4_Canal.nii' 
nifti_file = 'qulv/5530-3/5530-3ori_canal.nii'
#nifti_file = 'all_c_shape/canal-before.nii'
img = nib.load(nifti_file)
data = img.get_fdata()
num_slices = data.shape[2]  

# 初始化三维二值掩模
binary_volume = np.zeros_like(data, dtype=bool)

# 初始化中心线三维二值掩模
central_line_volume = np.zeros_like(data, dtype=bool)

# 找到最大圆
circles_info, binary_volume = search_circles(data, binary_volume)

# 打印所有区域的圆信息
for info in circles_info:
    slice_idx = info['slice']
    region_label = info['region_label']
    max_c = info['max_circle']
    sec_c = info['second_circle']
    thi_c = info['third_circle']
    print(f"Slice {slice_idx} - Region {region_label}:")
    print(f"  最大圆 - 圆心: {max_c['center']}, 半径: {max_c['radius']:.2f}")
    print(f"  第二个圆 - 圆心: {sec_c['center']}, 半径: {sec_c['radius']:.2f}")
    print(f"  第三个圆 - 圆心: {thi_c['center']}, 半径: {thi_c['radius']:.2f}")

# 允许的中心线两层之间最大距离
point_max_dist = 5

# 找中心线
central_lines = find_lines(circles_info, point_max_dist)

# 处理中心线，选择最长的四条并进行平滑
#central_smooth_line = process_central_lines(central_lines, window_size=9, top_n=4)
central_smooth_line = process_b_spline_central_lines(central_lines, smooth_factor=200, top_n=4)

# 打印结果验证
for line_name, smooth_line in central_smooth_line.items():
    print(f"{line_name}:")
    for point in smooth_line:
        print(f"  Layer {point['layer']}: Point {point['point']}")
    print("\n")

# 调用可视化函数
# visualize_lines(central_lines, central_smooth_line, num_samples=10)

# 将平滑后的中心线点转换为3D坐标，并在 central_line_volume 中设置相应的 voxels
for line_name, points in central_smooth_line.items():
    for point in points:
        y, x = point['point']
        z = point['layer']
        # 转换为整数索引
        y_int = int(round(y))
        x_int = int(round(x))
        z_int = int(z)
        # 边界检查
        if (0 <= y_int < data.shape[0] and
            0 <= x_int < data.shape[1] and
            0 <= z_int < data.shape[2]):
            central_line_volume[y_int, x_int, z_int] = True
        else:
            print(f"警告: 点 ({y_int}, {x_int}, {z_int}) 超出范围，未被添加到 central_line_volume。")

# 增强中心线的可视化（膨胀操作）
central_line_volume = morphology.binary_dilation(central_line_volume, morphology.ball(1))

# 生成三维表面网格
print("生成三维表面网格")
verts, faces, normals, values = measure.marching_cubes(binary_volume, level=0.5)
mesh_model = o3d.geometry.TriangleMesh()
mesh_model.vertices = o3d.utility.Vector3dVector(verts)
mesh_model.triangles = o3d.utility.Vector3iVector(faces)
mesh_model.compute_vertex_normals()
mesh_model.paint_uniform_color([0.7, 0.7, 0.7])  # 灰色
print("三维表面网格生成完毕.")

# 生成中心线的三维表面网格
print("生成中心线的三维表面网格")
verts_line, faces_line, normals_line, values_line = measure.marching_cubes(central_line_volume, level=0.5)
mesh_lines = o3d.geometry.TriangleMesh()
mesh_lines.vertices = o3d.utility.Vector3dVector(verts_line)
mesh_lines.triangles = o3d.utility.Vector3iVector(faces_line)
mesh_lines.compute_vertex_normals()
mesh_lines.paint_uniform_color([1, 0, 0])  # 红色
print("中心线的三维表面网格生成完毕.")

geometries = [mesh_model, mesh_lines]

# 可视化
print("可视化三维模型和中心线")
o3d.visualization.draw_geometries(
    geometries,
    window_name='3D Model with Central Lines',
    width=800,
    height=600,
    left=50,
    top=50,
    point_show_normal=False
)
# Out:
# Slice 0: 未检测到根管区域。
# Slice 1: 未检测到根管区域。
# Slice 2: 未检测到根管区域。
# Slice 3: 未检测到根管区域。
# Slice 4: 未检测到根管区域。
# Slice 5: 未检测到根管区域。
# Slice 6: 未检测到根管区域。
# Slice 7: 未检测到根管区域。
# Slice 8: 未检测到根管区域。
# Slice 9: 未检测到根管区域。
# Slice 10: 未检测到根管区域。
# Slice 11: 未检测到根管区域。
# Slice 12: 未检测到根管区域。
# Slice 13: 未检测到根管区域。
# Slice 14: 未检测到根管区域。
# Slice 15: 未检测到根管区域。
# Slice 16: 未检测到根管区域。
# Slice 17: 未检测到根管区域。
# Slice 582: 未检测到根管区域。
# Slice 583: 未检测到根管区域。
# Slice 584: 未检测到根管区域。
# Slice 585: 未检测到根管区域。
# Slice 586: 未检测到根管区域。
# Slice 587: 未检测到根管区域。
# Slice 588: 未检测到根管区域。
# Slice 589: 未检测到根管区域。
# Slice 590: 未检测到根管区域。
# Slice 591: 未检测到根管区域。
# Slice 592: 未检测到根管区域。
# Slice 593: 未检测到根管区域。
# Slice 594: 未检测到根管区域。
# Slice 595: 未检测到根管区域。
# Slice 596: 未检测到根管区域。
# Slice 597: 未检测到根管区域。
# Slice 598: 未检测到根管区域。
# Slice 599: 未检测到根管区域。
# Slice 600: 未检测到根管区域。
# Slice 601: 未检测到根管区域。
# Slice 602: 未检测到根管区域。
# Slice 603: 未检测到根管区域。
# Slice 604: 未检测到根管区域。
# Slice 605: 未检测到根管区域。
# Slice 606: 未检测到根管区域。
# Slice 607: 未检测到根管区域。
# Slice 608: 未检测到根管区域。
# Slice 609: 未检测到根管区域。
# Slice 610: 未检测到根管区域。
# Slice 611: 未检测到根管区域。
# Slice 612: 未检测到根管区域。
# Slice 613: 未检测到根管区域。
# Slice 614: 未检测到根管区域。
# Slice 615: 未检测到根管区域。
# Slice 616: 未检测到根管区域。
# Slice 617: 未检测到根管区域。
# Slice 618: 未检测到根管区域。
# Slice 619: 未检测到根管区域。
# Slice 620: 未检测到根管区域。
# Slice 621: 未检测到根管区域。
# Slice 622: 未检测到根管区域。
# Slice 623: 未检测到根管区域。
# Slice 624: 未检测到根管区域。
# Slice 625: 未检测到根管区域。
# Slice 626: 未检测到根管区域。
# Slice 627: 未检测到根管区域。
# Slice 628: 未检测到根管区域。
# Slice 629: 未检测到根管区域。
# Slice 630: 未检测到根管区域。
# Slice 631: 未检测到根管区域。
# Slice 632: 未检测到根管区域。
# Slice 633: 未检测到根管区域。
# Slice 634: 未检测到根管区域。
# Slice 635: 未检测到根管区域。
# Slice 636: 未检测到根管区域。
# Slice 637: 未检测到根管区域。
# Slice 638: 未检测到根管区域。
# Slice 639: 未检测到根管区域。
# Slice 640: 未检测到根管区域。
# Slice 641: 未检测到根管区域。
# Slice 642: 未检测到根管区域。
# Slice 643: 未检测到根管区域。
# Slice 644: 未检测到根管区域。
# Slice 645: 未检测到根管区域。
# Slice 646: 未检测到根管区域。
# Slice 647: 未检测到根管区域。
# Slice 648: 未检测到根管区域。
# Slice 649: 未检测到根管区域。
# Slice 650: 未检测到根管区域。
# Slice 651: 未检测到根管区域。
# Slice 652: 未检测到根管区域。
# Slice 653: 未检测到根管区域。
# Slice 654: 未检测到根管区域。
# Slice 655: 未检测到根管区域。
# Slice 656: 未检测到根管区域。
# Slice 657: 未检测到根管区域。
# Slice 658: 未检测到根管区域。
# Slice 659: 未检测到根管区域。
# Slice 660: 未检测到根管区域。
# Slice 661: 未检测到根管区域。
# Slice 662: 未检测到根管区域。
# Slice 663: 未检测到根管区域。
# Slice 664: 未检测到根管区域。
# Slice 665: 未检测到根管区域。
# Slice 666: 未检测到根管区域。
# Slice 667: 未检测到根管区域。
# Slice 668: 未检测到根管区域。
# Slice 669: 未检测到根管区域。
# Slice 670: 未检测到根管区域。
# Slice 671: 未检测到根管区域。
# Slice 672: 未检测到根管区域。
# Slice 673: 未检测到根管区域。
# Slice 674: 未检测到根管区域。
# Slice 675: 未检测到根管区域。
# Slice 676: 未检测到根管区域。
# Slice 677: 未检测到根管区域。
# Slice 678: 未检测到根管区域。
# Slice 679: 未检测到根管区域。
# Slice 680: 未检测到根管区域。
# Slice 681: 未检测到根管区域。
# Slice 682: 未检测到根管区域。
# Slice 683: 未检测到根管区域。
# Slice 684: 未检测到根管区域。
# Slice 685: 未检测到根管区域。
# Slice 686: 未检测到根管区域。
# Slice 687: 未检测到根管区域。
# Slice 688: 未检测到根管区域。
# Slice 689: 未检测到根管区域。
# Slice 690: 未检测到根管区域。
# Slice 691: 未检测到根管区域。
# Slice 692: 未检测到根管区域。
# Slice 18 - Region 1:
#   最大圆 - 圆心: (np.int64(105), np.int64(152)), 半径: 1.00
#   第二个圆 - 圆心: (np.int64(105), np.int64(152)), 半径: 1.00
#   第三个圆 - 圆心: (np.int64(105), np.int64(152)), 半径: 1.00
# Slice 19 - Region 1:
#   最大圆 - 圆心: (np.int64(105), np.int64(152)), 半径: 2.24
#   第二个圆 - 圆心: (np.int64(105), np.int64(152)), 半径: 2.24
#   第三个圆 - 圆心: (np.int64(105), np.int64(152)), 半径: 2.24
# Slice 20 - Region 1:
#   最大圆 - 圆心: (np.int64(105), np.int64(150)), 半径: 3.16
#   第二个圆 - 圆心: (np.int64(105), np.int64(150)), 半径: 3.16
#   第三个圆 - 圆心: (np.int64(105), np.int64(150)), 半径: 3.16
# Slice 21 - Region 1:
#   最大圆 - 圆心: (np.int64(104), np.int64(150)), 半径: 4.47
#   第二个圆 - 圆心: (np.int64(104), np.int64(150)), 半径: 4.47
#   第三个圆 - 圆心: (np.int64(104), np.int64(150)), 半径: 4.47
# Slice 22 - Region 1:
#   最大圆 - 圆心: (np.int64(103), np.int64(150)), 半径: 5.00
#   第二个圆 - 圆心: (np.int64(103), np.int64(150)), 半径: 5.00
#   第三个圆 - 圆心: (np.int64(103), np.int64(150)), 半径: 5.00
# Slice 23 - Region 1:
#   最大圆 - 圆心: (np.int64(103), np.int64(150)), 半径: 5.00
#   第二个圆 - 圆心: (np.int64(103), np.int64(150)), 半径: 5.00
#   第三个圆 - 圆心: (np.int64(103), np.int64(150)), 半径: 5.00
# Slice 24 - Region 1:
#   最大圆 - 圆心: (np.int64(104), np.int64(150)), 半径: 5.00
#   第二个圆 - 圆心: (np.int64(104), np.int64(150)), 半径: 5.00
#   第三个圆 - 圆心: (np.int64(104), np.int64(150)), 半径: 5.00
# Slice 24 - Region 2:
#   最大圆 - 圆心: (np.int64(191), np.int64(101)), 半径: 1.00
#   第二个圆 - 圆心: (np.int64(191), np.int64(101)), 半径: 1.00
#   第三个圆 - 圆心: (np.int64(191), np.int64(101)), 半径: 1.00
# Slice 25 - Region 1:
#   最大圆 - 圆心: (np.int64(105), np.int64(150)), 半径: 5.00
#   第二个圆 - 圆心: (np.int64(105), np.int64(150)), 半径: 5.00
#   第三个圆 - 圆心: (np.int64(105), np.int64(150)), 半径: 5.00
# Slice 25 - Region 2:
#   最大圆 - 圆心: (np.int64(192), np.int64(100)), 半径: 2.24
#   第二个圆 - 圆心: (np.int64(192), np.int64(100)), 半径: 2.24
#   第三个圆 - 圆心: (np.int64(192), np.int64(100)), 半径: 2.24
# Slice 26 - Region 1:
#   最大圆 - 圆心: (np.int64(106), np.int64(150)), 半径: 5.00
#   第二个圆 - 圆心: (np.int64(106), np.int64(150)), 半径: 5.00
#   第三个圆 - 圆心: (np.int64(106), np.int64(150)), 半径: 5.00
# Slice 26 - Region 2:
#   最大圆 - 圆心: (np.int64(194), np.int64(99)), 半径: 3.61
#   第二个圆 - 圆心: (np.int64(194), np.int64(99)), 半径: 3.61
#   第三个圆 - 圆心: (np.int64(194), np.int64(99)), 半径: 3.61
# Slice 26 - Region 3:
#   最大圆 - 圆心: (np.int64(224), np.int64(185)), 半径: 1.00
#   第二个圆 - 圆心: (np.int64(224), np.int64(185)), 半径: 1.00
#   第三个圆 - 圆心: (np.int64(224), np.int64(185)), 半径: 1.00
# Slice 27 - Region 1:
#   最大圆 - 圆心: (np.int64(107), np.int64(150)), 半径: 4.47
#   第二个圆 - 圆心: (np.int64(107), np.int64(150)), 半径: 4.47
#   第三个圆 - 圆心: (np.int64(107), np.int64(150)), 半径: 4.47
# Slice 27 - Region 2:
#   最大圆 - 圆心: (np.int64(194), np.int64(97)), 半径: 4.24
#   第二个圆 - 圆心: (np.int64(194), np.int64(97)), 半径: 4.24
#   第三个圆 - 圆心: (np.int64(194), np.int64(97)), 半径: 4.24
# Slice 27 - Region 3:
#   最大圆 - 圆心: (np.int64(224), np.int64(182)), 半径: 3.00
#   第二个圆 - 圆心: (np.int64(224), np.int64(182)), 半径: 3.00
#   第三个圆 - 圆心: (np.int64(224), np.int64(182)), 半径: 3.00
# Slice 28 - Region 1:
#   最大圆 - 圆心: (np.int64(108), np.int64(150)), 半径: 4.47
#   第二个圆 - 圆心: (np.int64(108), np.int64(150)), 半径: 4.47
#   第三个圆 - 圆心: (np.int64(108), np.int64(150)), 半径: 4.47
# Slice 28 - Region 2:
#   最大圆 - 圆心: (np.int64(195), np.int64(97)), 半径: 4.24
#   第二个圆 - 圆心: (np.int64(195), np.int64(97)), 半径: 4.24
#   第三个圆 - 圆心: (np.int64(195), np.int64(97)), 半径: 4.24
# Slice 28 - Region 3:
#   最大圆 - 圆心: (np.int64(223), np.int64(180)), 半径: 5.00
#   第二个圆 - 圆心: (np.int64(223), np.int64(180)), 半径: 5.00
#   第三个圆 - 圆心: (np.int64(223), np.int64(180)), 半径: 5.00
# Slice 29 - Region 1:
#   最大圆 - 圆心: (np.int64(108), np.int64(150)), 半径: 4.47
#   第二个圆 - 圆心: (np.int64(108), np.int64(150)), 半径: 4.47
#   第三个圆 - 圆心: (np.int64(108), np.int64(150)), 半径: 4.47
# Slice 29 - Region 2:
#   最大圆 - 圆心: (np.int64(195), np.int64(97)), 半径: 4.00
#   第二个圆 - 圆心: (np.int64(195), np.int64(97)), 半径: 4.00
#   第三个圆 - 圆心: (np.int64(195), np.int64(97)), 半径: 4.00
# Slice 29 - Region 3:
#   最大圆 - 圆心: (np.int64(223), np.int64(180)), 半径: 5.00
#   第二个圆 - 圆心: (np.int64(223), np.int64(180)), 半径: 5.00
#   第三个圆 - 圆心: (np.int64(223), np.int64(180)), 半径: 5.00
# Slice 30 - Region 1:
#   最大圆 - 圆心: (np.int64(109), np.int64(150)), 半径: 4.47
#   第二个圆 - 圆心: (np.int64(109), np.int64(150)), 半径: 4.47
#   第三个圆 - 圆心: (np.int64(109), np.int64(150)), 半径: 4.47
# Slice 30 - Region 2:
#   最大圆 - 圆心: (np.int64(196), np.int64(97)), 半径: 4.00
#   第二个圆 - 圆心: (np.int64(196), np.int64(97)), 半径: 4.00
#   第三个圆 - 圆心: (np.int64(196), np.int64(97)), 半径: 4.00
# Slice 30 - Region 3:
#   最大圆 - 圆心: (np.int64(224), np.int64(179)), 半径: 5.00
#   第二个圆 - 圆心: (np.int64(224), np.int64(179)), 半径: 5.00
#   第三个圆 - 圆心: (np.int64(224), np.int64(179)), 半径: 5.00
# Slice 31 - Region 1:
#   最大圆 - 圆心: (np.int64(109), np.int64(150)), 半径: 4.12
#   第二个圆 - 圆心: (np.int64(109), np.int64(150)), 半径: 4.12
#   第三个圆 - 圆心: (np.int64(109), np.int64(150)), 半径: 4.12
# Slice 31 - Region 2:
#   最大圆 - 圆心: (np.int64(196), np.int64(97)), 半径: 3.61
#   第二个圆 - 圆心: (np.int64(196), np.int64(97)), 半径: 3.61
#   第三个圆 - 圆心: (np.int64(196), np.int64(97)), 半径: 3.61
# Slice 31 - Region 3:
#   最大圆 - 圆心: (np.int64(224), np.int64(180)), 半径: 5.00
#   第二个圆 - 圆心: (np.int64(224), np.int64(180)), 半径: 5.00
#   第三个圆 - 圆心: (np.int64(224), np.int64(180)), 半径: 5.00
# Slice 32 - Region 1:
#   最大圆 - 圆心: (np.int64(110), np.int64(150)), 半径: 4.47
#   第二个圆 - 圆心: (np.int64(110), np.int64(150)), 半径: 4.47
#   第三个圆 - 圆心: (np.int64(110), np.int64(150)), 半径: 4.47
# Slice 32 - Region 2:
#   最大圆 - 圆心: (np.int64(197), np.int64(96)), 半径: 3.61
#   第二个圆 - 圆心: (np.int64(197), np.int64(96)), 半径: 3.61
#   第三个圆 - 圆心: (np.int64(197), np.int64(96)), 半径: 3.61
# Slice 32 - Region 3:
#   最大圆 - 圆心: (np.int64(224), np.int64(180)), 半径: 4.47
#   第二个圆 - 圆心: (np.int64(224), np.int64(180)), 半径: 4.47
#   第三个圆 - 圆心: (np.int64(224), np.int64(180)), 半径: 4.47
# Slice 33 - Region 1:
#   最大圆 - 圆心: (np.int64(111), np.int64(150)), 半径: 4.47
#   第二个圆 - 圆心: (np.int64(111), np.int64(150)), 半径: 4.47
#   第三个圆 - 圆心: (np.int64(111), np.int64(150)), 半径: 4.47
# Slice 33 - Region 2:
#   最大圆 - 圆心: (np.int64(197), np.int64(96)), 半径: 3.61
#   第二个圆 - 圆心: (np.int64(197), np.int64(96)), 半径: 3.61
#   第三个圆 - 圆心: (np.int64(197), np.int64(96)), 半径: 3.61
# Slice 33 - Region 3:
#   最大圆 - 圆心: (np.int64(225), np.int64(179)), 半径: 4.47
#   第二个圆 - 圆心: (np.int64(225), np.int64(179)), 半径: 4.47
#   第三个圆 - 圆心: (np.int64(225), np.int64(179)), 半径: 4.47
# Slice 34 - Region 1:
#   最大圆 - 圆心: (np.int64(111), np.int64(150)), 半径: 4.47
#   第二个圆 - 圆心: (np.int64(111), np.int64(150)), 半径: 4.47
#   第三个圆 - 圆心: (np.int64(111), np.int64(150)), 半径: 4.47
# Slice 34 - Region 2:
#   最大圆 - 圆心: (np.int64(197), np.int64(96)), 半径: 3.61
#   第二个圆 - 圆心: (np.int64(197), np.int64(96)), 半径: 3.61
#   第三个圆 - 圆心: (np.int64(197), np.int64(96)), 半径: 3.61
# Slice 34 - Region 3:
#   最大圆 - 圆心: (np.int64(225), np.int64(179)), 半径: 4.47
#   第二个圆 - 圆心: (np.int64(225), np.int64(179)), 半径: 4.47
#   第三个圆 - 圆心: (np.int64(225), np.int64(179)), 半径: 4.47
# Slice 35 - Region 1:
#   最大圆 - 圆心: (np.int64(112), np.int64(150)), 半径: 4.24
#   第二个圆 - 圆心: (np.int64(112), np.int64(150)), 半径: 4.24
#   第三个圆 - 圆心: (np.int64(112), np.int64(150)), 半径: 4.24
# Slice 35 - Region 2:
#   最大圆 - 圆心: (np.int64(198), np.int64(96)), 半径: 3.16
#   第二个圆 - 圆心: (np.int64(198), np.int64(96)), 半径: 3.16
#   第三个圆 - 圆心: (np.int64(198), np.int64(96)), 半径: 3.16
# Slice 35 - Region 3:
#   最大圆 - 圆心: (np.int64(225), np.int64(179)), 半径: 4.24
#   第二个圆 - 圆心: (np.int64(225), np.int64(179)), 半径: 4.24
#   第三个圆 - 圆心: (np.int64(225), np.int64(179)), 半径: 4.24
# Slice 36 - Region 1:
#   最大圆 - 圆心: (np.int64(112), np.int64(150)), 半径: 4.24
#   第二个圆 - 圆心: (np.int64(112), np.int64(150)), 半径: 4.24
#   第三个圆 - 圆心: (np.int64(112), np.int64(150)), 半径: 4.24
# Slice 36 - Region 2:
#   最大圆 - 圆心: (np.int64(198), np.int64(96)), 半径: 3.00
#   第二个圆 - 圆心: (np.int64(198), np.int64(96)), 半径: 3.00
#   第三个圆 - 圆心: (np.int64(198), np.int64(96)), 半径: 3.00
# Slice 36 - Region 3:
#   最大圆 - 圆心: (np.int64(224), np.int64(179)), 半径: 4.12
#   第二个圆 - 圆心: (np.int64(224), np.int64(179)), 半径: 4.12
#   第三个圆 - 圆心: (np.int64(224), np.int64(179)), 半径: 4.12
# Slice 37 - Region 1:
#   最大圆 - 圆心: (np.int64(112), np.int64(150)), 半径: 4.12
#   第二个圆 - 圆心: (np.int64(112), np.int64(150)), 半径: 4.12
#   第三个圆 - 圆心: (np.int64(112), np.int64(150)), 半径: 4.12
# Slice 37 - Region 2:
#   最大圆 - 圆心: (np.int64(198), np.int64(96)), 半径: 3.00
#   第二个圆 - 圆心: (np.int64(198), np.int64(96)), 半径: 3.00
#   第三个圆 - 圆心: (np.int64(198), np.int64(96)), 半径: 3.00
# Slice 37 - Region 3:
#   最大圆 - 圆心: (np.int64(224), np.int64(179)), 半径: 4.00
#   第二个圆 - 圆心: (np.int64(224), np.int64(179)), 半径: 4.00
#   第三个圆 - 圆心: (np.int64(224), np.int64(179)), 半径: 4.00
# Slice 38 - Region 1:
#   最大圆 - 圆心: (np.int64(105), np.int64(112)), 半径: 1.00
#   第二个圆 - 圆心: (np.int64(105), np.int64(112)), 半径: 1.00
#   第三个圆 - 圆心: (np.int64(105), np.int64(112)), 半径: 1.00
# Slice 38 - Region 2:
#   最大圆 - 圆心: (np.int64(113), np.int64(149)), 半径: 4.12
#   第二个圆 - 圆心: (np.int64(113), np.int64(149)), 半径: 4.12
#   第三个圆 - 圆心: (np.int64(113), np.int64(149)), 半径: 4.12
# Slice 38 - Region 3:
#   最大圆 - 圆心: (np.int64(198), np.int64(95)), 半径: 2.83
#   第二个圆 - 圆心: (np.int64(198), np.int64(95)), 半径: 2.83
#   第三个圆 - 圆心: (np.int64(198), np.int64(95)), 半径: 2.83
# Slice 38 - Region 4:
#   最大圆 - 圆心: (np.int64(225), np.int64(178)), 半径: 4.00
#   第二个圆 - 圆心: (np.int64(225), np.int64(178)), 半径: 4.00
#   第三个圆 - 圆心: (np.int64(225), np.int64(178)), 半径: 4.00
# Slice 39 - Region 1:
#   最大圆 - 圆心: (np.int64(106), np.int64(110)), 半径: 1.41
#   第二个圆 - 圆心: (np.int64(106), np.int64(110)), 半径: 1.41
#   第三个圆 - 圆心: (np.int64(106), np.int64(110)), 半径: 1.41
# Slice 39 - Region 2:
#   最大圆 - 圆心: (np.int64(112), np.int64(151)), 半径: 3.61
#   第二个圆 - 圆心: (np.int64(112), np.int64(151)), 半径: 3.61
#   第三个圆 - 圆心: (np.int64(112), np.int64(151)), 半径: 3.61
# Slice 39 - Region 3:
#   最大圆 - 圆心: (np.int64(198), np.int64(95)), 半径: 2.83
#   第二个圆 - 圆心: (np.int64(198), np.int64(95)), 半径: 2.83
#   第三个圆 - 圆心: (np.int64(198), np.int64(95)), 半径: 2.83
# Slice 39 - Region 4:
#   最大圆 - 圆心: (np.int64(225), np.int64(178)), 半径: 3.61
#   第二个圆 - 圆心: (np.int64(225), np.int64(178)), 半径: 3.61
#   第三个圆 - 圆心: (np.int64(225), np.int64(178)), 半径: 3.61
# Slice 40 - Region 1:
#   最大圆 - 圆心: (np.int64(106), np.int64(109)), 半径: 2.00
#   第二个圆 - 圆心: (np.int64(106), np.int64(109)), 半径: 2.00
#   第三个圆 - 圆心: (np.int64(106), np.int64(109)), 半径: 2.00
# Slice 40 - Region 2:
#   最大圆 - 圆心: (np.int64(113), np.int64(149)), 半径: 3.61
#   第二个圆 - 圆心: (np.int64(113), np.int64(149)), 半径: 3.61
#   第三个圆 - 圆心: (np.int64(113), np.int64(149)), 半径: 3.61
# Slice 40 - Region 3:
#   最大圆 - 圆心: (np.int64(198), np.int64(95)), 半径: 2.83
#   第二个圆 - 圆心: (np.int64(198), np.int64(95)), 半径: 2.83
#   第三个圆 - 圆心: (np.int64(198), np.int64(95)), 半径: 2.83
# Slice 40 - Region 4:
#   最大圆 - 圆心: (np.int64(225), np.int64(178)), 半径: 3.61
#   第二个圆 - 圆心: (np.int64(225), np.int64(178)), 半径: 3.61
#   第三个圆 - 圆心: (np.int64(225), np.int64(178)), 半径: 3.61
# Slice 41 - Region 1:
#   最大圆 - 圆心: (np.int64(106), np.int64(108)), 半径: 2.24
#   第二个圆 - 圆心: (np.int64(106), np.int64(108)), 半径: 2.24
#   第三个圆 - 圆心: (np.int64(106), np.int64(108)), 半径: 2.24
# Slice 41 - Region 2:
#   最大圆 - 圆心: (np.int64(113), np.int64(149)), 半径: 3.61
#   第二个圆 - 圆心: (np.int64(113), np.int64(149)), 半径: 3.61
#   第三个圆 - 圆心: (np.int64(113), np.int64(149)), 半径: 3.61
# Slice 41 - Region 3:
#   最大圆 - 圆心: (np.int64(199), np.int64(95)), 半径: 2.83
#   第二个圆 - 圆心: (np.int64(199), np.int64(95)), 半径: 2.83
#   第三个圆 - 圆心: (np.int64(199), np.int64(95)), 半径: 2.83
# Slice 41 - Region 4:
#   最大圆 - 圆心: (np.int64(225), np.int64(179)), 半径: 3.16
#   第二个圆 - 圆心: (np.int64(225), np.int64(179)), 半径: 3.16
#   第三个圆 - 圆心: (np.int64(225), np.int64(179)), 半径: 3.16
# Slice 42 - Region 1:
#   最大圆 - 圆心: (np.int64(105), np.int64(109)), 半径: 2.83
#   第二个圆 - 圆心: (np.int64(105), np.int64(109)), 半径: 2.83
#   第三个圆 - 圆心: (np.int64(105), np.int64(109)), 半径: 2.83
# Slice 42 - Region 2:
#   最大圆 - 圆心: (np.int64(113), np.int64(149)), 半径: 3.61
#   第二个圆 - 圆心: (np.int64(113), np.int64(149)), 半径: 3.61
#   第三个圆 - 圆心: (np.int64(113), np.int64(149)), 半径: 3.61
# Slice 42 - Region 3:
#   最大圆 - 圆心: (np.int64(199), np.int64(95)), 半径: 2.83
#   第二个圆 - 圆心: (np.int64(199), np.int64(95)), 半径: 2.83
#   第三个圆 - 圆心: (np.int64(199), np.int64(95)), 半径: 2.83
# Slice 42 - Region 4:
#   最大圆 - 圆心: (np.int64(225), np.int64(179)), 半径: 3.61
#   第二个圆 - 圆心: (np.int64(225), np.int64(179)), 半径: 3.61
#   第三个圆 - 圆心: (np.int64(225), np.int64(179)), 半径: 3.61
# Slice 43 - Region 1:
#   最大圆 - 圆心: (np.int64(105), np.int64(108)), 半径: 3.61
#   第二个圆 - 圆心: (np.int64(105), np.int64(108)), 半径: 3.61
#   第三个圆 - 圆心: (np.int64(105), np.int64(108)), 半径: 3.61
# Slice 43 - Region 2:
#   最大圆 - 圆心: (np.int64(113), np.int64(149)), 半径: 3.61
#   第二个圆 - 圆心: (np.int64(113), np.int64(149)), 半径: 3.61
#   第三个圆 - 圆心: (np.int64(113), np.int64(149)), 半径: 3.61
# Slice 43 - Region 3:
#   最大圆 - 圆心: (np.int64(199), np.int64(95)), 半径: 2.83
#   第二个圆 - 圆心: (np.int64(199), np.int64(95)), 半径: 2.83
#   第三个圆 - 圆心: (np.int64(199), np.int64(95)), 半径: 2.83
# Slice 43 - Region 4:
#   最大圆 - 圆心: (np.int64(225), np.int64(179)), 半径: 3.61
#   第二个圆 - 圆心: (np.int64(225), np.int64(179)), 半径: 3.61
#   第三个圆 - 圆心: (np.int64(225), np.int64(179)), 半径: 3.61
# Slice 44 - Region 1:
#   最大圆 - 圆心: (np.int64(106), np.int64(106)), 半径: 4.12
#   第二个圆 - 圆心: (np.int64(106), np.int64(106)), 半径: 4.12
#   第三个圆 - 圆心: (np.int64(106), np.int64(106)), 半径: 4.12
# Slice 44 - Region 2:
#   最大圆 - 圆心: (np.int64(113), np.int64(149)), 半径: 3.16
#   第二个圆 - 圆心: (np.int64(113), np.int64(149)), 半径: 3.16
#   第三个圆 - 圆心: (np.int64(113), np.int64(149)), 半径: 3.16
# Slice 44 - Region 3:
#   最大圆 - 圆心: (np.int64(199), np.int64(95)), 半径: 2.00
#   第二个圆 - 圆心: (np.int64(199), np.int64(95)), 半径: 2.00
#   第三个圆 - 圆心: (np.int64(199), np.int64(95)), 半径: 2.00
# Slice 44 - Region 4:
#   最大圆 - 圆心: (np.int64(225), np.int64(179)), 半径: 3.61
#   第二个圆 - 圆心: (np.int64(225), np.int64(179)), 半径: 3.61
#   第三个圆 - 圆心: (np.int64(225), np.int64(179)), 半径: 3.61
# Slice 45 - Region 1:
#   最大圆 - 圆心: (np.int64(106), np.int64(106)), 半径: 5.00
#   第二个圆 - 圆心: (np.int64(106), np.int64(106)), 半径: 5.00
#   第三个圆 - 圆心: (np.int64(106), np.int64(106)), 半径: 5.00
# Slice 45 - Region 2:
#   最大圆 - 圆心: (np.int64(112), np.int64(151)), 半径: 3.00
#   第二个圆 - 圆心: (np.int64(112), np.int64(151)), 半径: 3.00
#   第三个圆 - 圆心: (np.int64(112), np.int64(151)), 半径: 3.00
# Slice 45 - Region 3:
#   最大圆 - 圆心: (np.int64(200), np.int64(95)), 半径: 2.00
#   第二个圆 - 圆心: (np.int64(200), np.int64(95)), 半径: 2.00
#   第三个圆 - 圆心: (np.int64(200), np.int64(95)), 半径: 2.00
# Slice 45 - Region 4:
#   最大圆 - 圆心: (np.int64(226), np.int64(179)), 半径: 3.61
#   第二个圆 - 圆心: (np.int64(226), np.int64(179)), 半径: 3.61
#   第三个圆 - 圆心: (np.int64(226), np.int64(179)), 半径: 3.61
# Slice 46 - Region 1:
#   最大圆 - 圆心: (np.int64(105), np.int64(106)), 半径: 5.00
#   第二个圆 - 圆心: (np.int64(105), np.int64(106)), 半径: 5.00
#   第三个圆 - 圆心: (np.int64(105), np.int64(106)), 半径: 5.00
# Slice 46 - Region 2:
#   最大圆 - 圆心: (np.int64(112), np.int64(151)), 半径: 3.00
#   第二个圆 - 圆心: (np.int64(112), np.int64(151)), 半径: 3.00
#   第三个圆 - 圆心: (np.int64(112), np.int64(151)), 半径: 3.00
# Slice 46 - Region 3:
#   最大圆 - 圆心: (np.int64(201), np.int64(95)), 半径: 2.00
#   第二个圆 - 圆心: (np.int64(201), np.int64(95)), 半径: 2.00
#   第三个圆 - 圆心: (np.int64(201), np.int64(95)), 半径: 2.00
# Slice 46 - Region 4:
#   最大圆 - 圆心: (np.int64(226), np.int64(179)), 半径: 3.61
#   第二个圆 - 圆心: (np.int64(226), np.int64(179)), 半径: 3.61
#   第三个圆 - 圆心: (np.int64(226), np.int64(179)), 半径: 3.61
# Slice 47 - Region 1:
#   最大圆 - 圆心: (np.int64(105), np.int64(106)), 半径: 5.39
#   第二个圆 - 圆心: (np.int64(105), np.int64(106)), 半径: 5.39
#   第三个圆 - 圆心: (np.int64(105), np.int64(106)), 半径: 5.39
# Slice 47 - Region 2:
#   最大圆 - 圆心: (np.int64(112), np.int64(151)), 半径: 3.16
#   第二个圆 - 圆心: (np.int64(112), np.int64(151)), 半径: 3.16
#   第三个圆 - 圆心: (np.int64(112), np.int64(151)), 半径: 3.16
# Slice 47 - Region 3:
#   最大圆 - 圆心: (np.int64(201), np.int64(95)), 半径: 1.41
#   第二个圆 - 圆心: (np.int64(201), np.int64(95)), 半径: 1.41
#   第三个圆 - 圆心: (np.int64(201), np.int64(95)), 半径: 1.41
# Slice 47 - Region 4:
#   最大圆 - 圆心: (np.int64(227), np.int64(179)), 半径: 3.61
#   第二个圆 - 圆心: (np.int64(227), np.int64(179)), 半径: 3.61
#   第三个圆 - 圆心: (np.int64(227), np.int64(179)), 半径: 3.61
# Slice 48 - Region 1:
#   最大圆 - 圆心: (np.int64(105), np.int64(105)), 半径: 5.83
#   第二个圆 - 圆心: (np.int64(105), np.int64(105)), 半径: 5.83
#   第三个圆 - 圆心: (np.int64(105), np.int64(105)), 半径: 5.83
# Slice 48 - Region 2:
#   最大圆 - 圆心: (np.int64(112), np.int64(152)), 半径: 3.61
#   第二个圆 - 圆心: (np.int64(112), np.int64(152)), 半径: 3.61
#   第三个圆 - 圆心: (np.int64(112), np.int64(152)), 半径: 3.61
# Slice 48 - Region 3:
#   最大圆 - 圆心: (np.int64(201), np.int64(94)), 半径: 1.00
#   第二个圆 - 圆心: (np.int64(201), np.int64(94)), 半径: 1.00
#   第三个圆 - 圆心: (np.int64(201), np.int64(94)), 半径: 1.00
# Slice 48 - Region 4:
#   最大圆 - 圆心: (np.int64(228), np.int64(179)), 半径: 3.61
#   第二个圆 - 圆心: (np.int64(228), np.int64(179)), 半径: 3.61
#   第三个圆 - 圆心: (np.int64(228), np.int64(179)), 半径: 3.61
# Slice 49 - Region 1:
#   最大圆 - 圆心: (np.int64(104), np.int64(106)), 半径: 5.83
#   第二个圆 - 圆心: (np.int64(104), np.int64(106)), 半径: 5.83
#   第三个圆 - 圆心: (np.int64(104), np.int64(106)), 半径: 5.83
# Slice 49 - Region 2:
#   最大圆 - 圆心: (np.int64(112), np.int64(152)), 半径: 3.61
#   第二个圆 - 圆心: (np.int64(112), np.int64(152)), 半径: 3.61
#   第三个圆 - 圆心: (np.int64(112), np.int64(152)), 半径: 3.61
# Slice 49 - Region 3:
#   最大圆 - 圆心: (np.int64(201), np.int64(94)), 半径: 1.00
#   第二个圆 - 圆心: (np.int64(201), np.int64(94)), 半径: 1.00
#   第三个圆 - 圆心: (np.int64(201), np.int64(94)), 半径: 1.00
# Slice 49 - Region 4:
#   最大圆 - 圆心: (np.int64(228), np.int64(179)), 半径: 3.61
#   第二个圆 - 圆心: (np.int64(228), np.int64(179)), 半径: 3.61
#   第三个圆 - 圆心: (np.int64(228), np.int64(179)), 半径: 3.61
# Slice 50 - Region 1:
#   最大圆 - 圆心: (np.int64(104), np.int64(106)), 半径: 5.83
#   第二个圆 - 圆心: (np.int64(104), np.int64(106)), 半径: 5.83
#   第三个圆 - 圆心: (np.int64(104), np.int64(106)), 半径: 5.83
# Slice 50 - Region 2:
#   最大圆 - 圆心: (np.int64(112), np.int64(152)), 半径: 3.61
#   第二个圆 - 圆心: (np.int64(112), np.int64(152)), 半径: 3.61
#   第三个圆 - 圆心: (np.int64(112), np.int64(152)), 半径: 3.61
# Slice 50 - Region 3:
#   最大圆 - 圆心: (np.int64(201), np.int64(94)), 半径: 1.00
#   第二个圆 - 圆心: (np.int64(201), np.int64(94)), 半径: 1.00
#   第三个圆 - 圆心: (np.int64(201), np.int64(94)), 半径: 1.00
# Slice 50 - Region 4:
#   最大圆 - 圆心: (np.int64(229), np.int64(178)), 半径: 3.61
#   第二个圆 - 圆心: (np.int64(229), np.int64(178)), 半径: 3.61
#   第三个圆 - 圆心: (np.int64(229), np.int64(178)), 半径: 3.61
# Slice 51 - Region 1:
#   最大圆 - 圆心: (np.int64(103), np.int64(106)), 半径: 5.00
#   第二个圆 - 圆心: (np.int64(103), np.int64(106)), 半径: 5.00
#   第三个圆 - 圆心: (np.int64(103), np.int64(106)), 半径: 5.00
# Slice 51 - Region 2:
#   最大圆 - 圆心: (np.int64(112), np.int64(152)), 半径: 3.61
#   第二个圆 - 圆心: (np.int64(112), np.int64(152)), 半径: 3.61
#   第三个圆 - 圆心: (np.int64(112), np.int64(152)), 半径: 3.61
# Slice 51 - Region 3:
#   最大圆 - 圆心: (np.int64(201), np.int64(94)), 半径: 1.00
#   第二个圆 - 圆心: (np.int64(201), np.int64(94)), 半径: 1.00
#   第三个圆 - 圆心: (np.int64(201), np.int64(94)), 半径: 1.00
# Slice 51 - Region 4:
#   最大圆 - 圆心: (np.int64(229), np.int64(178)), 半径: 3.61
#   第二个圆 - 圆心: (np.int64(229), np.int64(178)), 半径: 3.61
#   第三个圆 - 圆心: (np.int64(229), np.int64(178)), 半径: 3.61
# Slice 52 - Region 1:
#   最大圆 - 圆心: (np.int64(105), np.int64(106)), 半径: 5.00
#   第二个圆 - 圆心: (np.int64(105), np.int64(106)), 半径: 5.00
#   第三个圆 - 圆心: (np.int64(105), np.int64(106)), 半径: 5.00
# Slice 52 - Region 2:
#   最大圆 - 圆心: (np.int64(112), np.int64(152)), 半径: 3.61
#   第二个圆 - 圆心: (np.int64(112), np.int64(152)), 半径: 3.61
#   第三个圆 - 圆心: (np.int64(112), np.int64(152)), 半径: 3.61
# Slice 52 - Region 3:
#   最大圆 - 圆心: (np.int64(201), np.int64(94)), 半径: 1.00
#   第二个圆 - 圆心: (np.int64(201), np.int64(94)), 半径: 1.00
#   第三个圆 - 圆心: (np.int64(201), np.int64(94)), 半径: 1.00
# Slice 52 - Region 4:
#   最大圆 - 圆心: (np.int64(229), np.int64(178)), 半径: 3.16
#   第二个圆 - 圆心: (np.int64(229), np.int64(178)), 半径: 3.16
#   第三个圆 - 圆心: (np.int64(229), np.int64(178)), 半径: 3.16
# Slice 53 - Region 1:
#   最大圆 - 圆心: (np.int64(107), np.int64(106)), 半径: 5.00
#   第二个圆 - 圆心: (np.int64(107), np.int64(106)), 半径: 5.00
#   第三个圆 - 圆心: (np.int64(107), np.int64(106)), 半径: 5.00
# Slice 53 - Region 2:
#   最大圆 - 圆心: (np.int64(112), np.int64(152)), 半径: 3.16
#   第二个圆 - 圆心: (np.int64(112), np.int64(152)), 半径: 3.16
#   第三个圆 - 圆心: (np.int64(112), np.int64(152)), 半径: 3.16
# Slice 53 - Region 3:
#   最大圆 - 圆心: (np.int64(201), np.int64(94)), 半径: 1.00
#   第二个圆 - 圆心: (np.int64(201), np.int64(94)), 半径: 1.00
#   第三个圆 - 圆心: (np.int64(201), np.int64(94)), 半径: 1.00
# Slice 53 - Region 4:
#   最大圆 - 圆心: (np.int64(229), np.int64(178)), 半径: 3.00
#   第二个圆 - 圆心: (np.int64(229), np.int64(178)), 半径: 3.00
#   第三个圆 - 圆心: (np.int64(229), np.int64(178)), 半径: 3.00
# Slice 54 - Region 1:
#   最大圆 - 圆心: (np.int64(109), np.int64(106)), 半径: 5.39
#   第二个圆 - 圆心: (np.int64(109), np.int64(106)), 半径: 5.39
#   第三个圆 - 圆心: (np.int64(109), np.int64(106)), 半径: 5.39
# Slice 54 - Region 2:
#   最大圆 - 圆心: (np.int64(112), np.int64(153)), 半径: 3.16
#   第二个圆 - 圆心: (np.int64(112), np.int64(153)), 半径: 3.16
#   第三个圆 - 圆心: (np.int64(112), np.int64(153)), 半径: 3.16
# Slice 54 - Region 3:
#   最大圆 - 圆心: (np.int64(202), np.int64(94)), 半径: 1.41
#   第二个圆 - 圆心: (np.int64(202), np.int64(94)), 半径: 1.41
#   第三个圆 - 圆心: (np.int64(202), np.int64(94)), 半径: 1.41
# Slice 54 - Region 4:
#   最大圆 - 圆心: (np.int64(230), np.int64(178)), 半径: 3.16
#   第二个圆 - 圆心: (np.int64(230), np.int64(178)), 半径: 3.16
#   第三个圆 - 圆心: (np.int64(230), np.int64(178)), 半径: 3.16
# Slice 55 - Region 1:
#   最大圆 - 圆心: (np.int64(110), np.int64(106)), 半径: 5.66
#   第二个圆 - 圆心: (np.int64(110), np.int64(106)), 半径: 5.66
#   第三个圆 - 圆心: (np.int64(110), np.int64(106)), 半径: 5.66
# Slice 55 - Region 2:
#   最大圆 - 圆心: (np.int64(112), np.int64(153)), 半径: 3.00
#   第二个圆 - 圆心: (np.int64(112), np.int64(153)), 半径: 3.00
#   第三个圆 - 圆心: (np.int64(112), np.int64(153)), 半径: 3.00
# Slice 55 - Region 3:
#   最大圆 - 圆心: (np.int64(202), np.int64(94)), 半径: 1.41
#   第二个圆 - 圆心: (np.int64(202), np.int64(94)), 半径: 1.41
#   第三个圆 - 圆心: (np.int64(202), np.int64(94)), 半径: 1.41
# Slice 55 - Region 4:
#   最大圆 - 圆心: (np.int64(230), np.int64(178)), 半径: 3.16
#   第二个圆 - 圆心: (np.int64(230), np.int64(178)), 半径: 3.16
#   第三个圆 - 圆心: (np.int64(230), np.int64(178)), 半径: 3.16
# Slice 56 - Region 1:
#   最大圆 - 圆心: (np.int64(110), np.int64(106)), 半径: 5.39
#   第二个圆 - 圆心: (np.int64(110), np.int64(106)), 半径: 5.39
#   第三个圆 - 圆心: (np.int64(110), np.int64(106)), 半径: 5.39
# Slice 56 - Region 2:
#   最大圆 - 圆心: (np.int64(112), np.int64(153)), 半径: 3.16
#   第二个圆 - 圆心: (np.int64(112), np.int64(153)), 半径: 3.16
#   第三个圆 - 圆心: (np.int64(112), np.int64(153)), 半径: 3.16
# Slice 56 - Region 3:
#   最大圆 - 圆心: (np.int64(202), np.int64(94)), 半径: 1.41
#   第二个圆 - 圆心: (np.int64(202), np.int64(94)), 半径: 1.41
#   第三个圆 - 圆心: (np.int64(202), np.int64(94)), 半径: 1.41
# Slice 56 - Region 4:
#   最大圆 - 圆心: (np.int64(230), np.int64(179)), 半径: 3.61
#   第二个圆 - 圆心: (np.int64(230), np.int64(179)), 半径: 3.61
#   第三个圆 - 圆心: (np.int64(230), np.int64(179)), 半径: 3.61
# Slice 57 - Region 1:
#   最大圆 - 圆心: (np.int64(111), np.int64(106)), 半径: 5.66
#   第二个圆 - 圆心: (np.int64(111), np.int64(106)), 半径: 5.66
#   第三个圆 - 圆心: (np.int64(111), np.int64(106)), 半径: 5.66
# Slice 57 - Region 2:
#   最大圆 - 圆心: (np.int64(112), np.int64(153)), 半径: 3.16
#   第二个圆 - 圆心: (np.int64(112), np.int64(153)), 半径: 3.16
#   第三个圆 - 圆心: (np.int64(112), np.int64(153)), 半径: 3.16
# Slice 57 - Region 3:
#   最大圆 - 圆心: (np.int64(201), np.int64(94)), 半径: 1.41
#   第二个圆 - 圆心: (np.int64(201), np.int64(94)), 半径: 1.41
#   第三个圆 - 圆心: (np.int64(201), np.int64(94)), 半径: 1.41
# Slice 57 - Region 4:
#   最大圆 - 圆心: (np.int64(231), np.int64(179)), 半径: 3.61
#   第二个圆 - 圆心: (np.int64(231), np.int64(179)), 半径: 3.61
#   第三个圆 - 圆心: (np.int64(231), np.int64(179)), 半径: 3.61
# Slice 58 - Region 1:
#   最大圆 - 圆心: (np.int64(111), np.int64(106)), 半径: 5.00
#   第二个圆 - 圆心: (np.int64(111), np.int64(106)), 半径: 5.00
#   第三个圆 - 圆心: (np.int64(111), np.int64(106)), 半径: 5.00
# Slice 58 - Region 2:
#   最大圆 - 圆心: (np.int64(112), np.int64(154)), 半径: 3.00
#   第二个圆 - 圆心: (np.int64(112), np.int64(154)), 半径: 3.00
#   第三个圆 - 圆心: (np.int64(112), np.int64(154)), 半径: 3.00
# Slice 58 - Region 3:
#   最大圆 - 圆心: (np.int64(201), np.int64(94)), 半径: 1.41
#   第二个圆 - 圆心: (np.int64(201), np.int64(94)), 半径: 1.41
#   第三个圆 - 圆心: (np.int64(201), np.int64(94)), 半径: 1.41
# Slice 58 - Region 4:
#   最大圆 - 圆心: (np.int64(231), np.int64(179)), 半径: 3.61
#   第二个圆 - 圆心: (np.int64(231), np.int64(179)), 半径: 3.61
#   第三个圆 - 圆心: (np.int64(231), np.int64(179)), 半径: 3.61
# Slice 59 - Region 1:
#   最大圆 - 圆心: (np.int64(112), np.int64(106)), 半径: 5.10
#   第二个圆 - 圆心: (np.int64(112), np.int64(106)), 半径: 5.10
#   第三个圆 - 圆心: (np.int64(112), np.int64(106)), 半径: 5.10
# Slice 59 - Region 2:
#   最大圆 - 圆心: (np.int64(112), np.int64(154)), 半径: 3.00
#   第二个圆 - 圆心: (np.int64(112), np.int64(154)), 半径: 3.00
#   第三个圆 - 圆心: (np.int64(112), np.int64(154)), 半径: 3.00
# Slice 59 - Region 3:
#   最大圆 - 圆心: (np.int64(202), np.int64(94)), 半径: 1.41
#   第二个圆 - 圆心: (np.int64(202), np.int64(94)), 半径: 1.41
#   第三个圆 - 圆心: (np.int64(202), np.int64(94)), 半径: 1.41
# Slice 59 - Region 4:
#   最大圆 - 圆心: (np.int64(231), np.int64(179)), 半径: 3.61
#   第二个圆 - 圆心: (np.int64(231), np.int64(179)), 半径: 3.61
#   第三个圆 - 圆心: (np.int64(231), np.int64(179)), 半径: 3.61
# Slice 60 - Region 1:
#   最大圆 - 圆心: (np.int64(113), np.int64(106)), 半径: 5.10
#   第二个圆 - 圆心: (np.int64(113), np.int64(106)), 半径: 5.10
#   第三个圆 - 圆心: (np.int64(113), np.int64(106)), 半径: 5.10
# Slice 60 - Region 2:
#   最大圆 - 圆心: (np.int64(111), np.int64(155)), 半径: 3.00
#   第二个圆 - 圆心: (np.int64(111), np.int64(155)), 半径: 3.00
#   第三个圆 - 圆心: (np.int64(111), np.int64(155)), 半径: 3.00
# Slice 60 - Region 3:
#   最大圆 - 圆心: (np.int64(202), np.int64(94)), 半径: 1.41
#   第二个圆 - 圆心: (np.int64(202), np.int64(94)), 半径: 1.41
#   第三个圆 - 圆心: (np.int64(202), np.int64(94)), 半径: 1.41
# Slice 60 - Region 4:
#   最大圆 - 圆心: (np.int64(231), np.int64(179)), 半径: 3.16
#   第二个圆 - 圆心: (np.int64(231), np.int64(179)), 半径: 3.16
#   第三个圆 - 圆心: (np.int64(231), np.int64(179)), 半径: 3.16
# Slice 61 - Region 1:
#   最大圆 - 圆心: (np.int64(113), np.int64(106)), 半径: 5.10
#   第二个圆 - 圆心: (np.int64(113), np.int64(106)), 半径: 5.10
#   第三个圆 - 圆心: (np.int64(113), np.int64(106)), 半径: 5.10
# Slice 61 - Region 2:
#   最大圆 - 圆心: (np.int64(111), np.int64(155)), 半径: 3.00
#   第二个圆 - 圆心: (np.int64(111), np.int64(155)), 半径: 3.00
#   第三个圆 - 圆心: (np.int64(111), np.int64(155)), 半径: 3.00
# Slice 61 - Region 3:
#   最大圆 - 圆心: (np.int64(201), np.int64(94)), 半径: 1.00
#   第二个圆 - 圆心: (np.int64(201), np.int64(94)), 半径: 1.00
#   第三个圆 - 圆心: (np.int64(201), np.int64(94)), 半径: 1.00
# Slice 61 - Region 4:
#   最大圆 - 圆心: (np.int64(232), np.int64(179)), 半径: 3.61
#   第二个圆 - 圆心: (np.int64(232), np.int64(179)), 半径: 3.61
#   第三个圆 - 圆心: (np.int64(232), np.int64(179)), 半径: 3.61
# Slice 62 - Region 1:
#   最大圆 - 圆心: (np.int64(114), np.int64(106)), 半径: 5.00
#   第二个圆 - 圆心: (np.int64(114), np.int64(106)), 半径: 5.00
#   第三个圆 - 圆心: (np.int64(114), np.int64(106)), 半径: 5.00
# Slice 62 - Region 2:
#   最大圆 - 圆心: (np.int64(111), np.int64(156)), 半径: 3.00
#   第二个圆 - 圆心: (np.int64(111), np.int64(156)), 半径: 3.00
#   第三个圆 - 圆心: (np.int64(111), np.int64(156)), 半径: 3.00
# Slice 62 - Region 3:
#   最大圆 - 圆心: (np.int64(201), np.int64(94)), 半径: 1.00
#   第二个圆 - 圆心: (np.int64(201), np.int64(94)), 半径: 1.00
#   第三个圆 - 圆心: (np.int64(201), np.int64(94)), 半径: 1.00
# Slice 62 - Region 4:
#   最大圆 - 圆心: (np.int64(232), np.int64(180)), 半径: 3.61
#   第二个圆 - 圆心: (np.int64(232), np.int64(180)), 半径: 3.61
#   第三个圆 - 圆心: (np.int64(232), np.int64(180)), 半径: 3.61
# Slice 63 - Region 1:
#   最大圆 - 圆心: (np.int64(111), np.int64(156)), 半径: 3.16
#   第二个圆 - 圆心: (np.int64(111), np.int64(156)), 半径: 3.16
#   第三个圆 - 圆心: (np.int64(111), np.int64(156)), 半径: 3.16
# Slice 63 - Region 2:
#   最大圆 - 圆心: (np.int64(114), np.int64(106)), 半径: 5.00
#   第二个圆 - 圆心: (np.int64(114), np.int64(106)), 半径: 5.00
#   第三个圆 - 圆心: (np.int64(114), np.int64(106)), 半径: 5.00
# Slice 63 - Region 3:
#   最大圆 - 圆心: (np.int64(201), np.int64(93)), 半径: 1.00
#   第二个圆 - 圆心: (np.int64(201), np.int64(93)), 半径: 1.00
#   第三个圆 - 圆心: (np.int64(201), np.int64(93)), 半径: 1.00
# Slice 63 - Region 4:
#   最大圆 - 圆心: (np.int64(232), np.int64(180)), 半径: 3.16
#   第二个圆 - 圆心: (np.int64(232), np.int64(180)), 半径: 3.16
#   第三个圆 - 圆心: (np.int64(232), np.int64(180)), 半径: 3.16
# Slice 64 - Region 1:
#   最大圆 - 圆心: (np.int64(111), np.int64(156)), 半径: 3.16
#   第二个圆 - 圆心: (np.int64(111), np.int64(156)), 半径: 3.16
#   第三个圆 - 圆心: (np.int64(111), np.int64(156)), 半径: 3.16
# Slice 64 - Region 2:
#   最大圆 - 圆心: (np.int64(114), np.int64(106)), 半径: 4.47
#   第二个圆 - 圆心: (np.int64(114), np.int64(106)), 半径: 4.47
#   第三个圆 - 圆心: (np.int64(114), np.int64(106)), 半径: 4.47
# Slice 64 - Region 3:
#   最大圆 - 圆心: (np.int64(201), np.int64(93)), 半径: 1.00
#   第二个圆 - 圆心: (np.int64(201), np.int64(93)), 半径: 1.00
#   第三个圆 - 圆心: (np.int64(201), np.int64(93)), 半径: 1.00
# Slice 64 - Region 4:
#   最大圆 - 圆心: (np.int64(233), np.int64(181)), 半径: 3.16
#   第二个圆 - 圆心: (np.int64(233), np.int64(181)), 半径: 3.16
#   第三个圆 - 圆心: (np.int64(233), np.int64(181)), 半径: 3.16
# Slice 65 - Region 1:
#   最大圆 - 圆心: (np.int64(111), np.int64(156)), 半径: 3.00
#   第二个圆 - 圆心: (np.int64(111), np.int64(156)), 半径: 3.00
#   第三个圆 - 圆心: (np.int64(111), np.int64(156)), 半径: 3.00
# Slice 65 - Region 2:
#   最大圆 - 圆心: (np.int64(115), np.int64(106)), 半径: 4.47
#   第二个圆 - 圆心: (np.int64(115), np.int64(106)), 半径: 4.47
#   第三个圆 - 圆心: (np.int64(115), np.int64(106)), 半径: 4.47
# Slice 65 - Region 3:
#   最大圆 - 圆心: (np.int64(201), np.int64(93)), 半径: 1.00
#   第二个圆 - 圆心: (np.int64(201), np.int64(93)), 半径: 1.00
#   第三个圆 - 圆心: (np.int64(201), np.int64(93)), 半径: 1.00
# Slice 65 - Region 4:
#   最大圆 - 圆心: (np.int64(233), np.int64(181)), 半径: 3.61
#   第二个圆 - 圆心: (np.int64(233), np.int64(181)), 半径: 3.61
#   第三个圆 - 圆心: (np.int64(233), np.int64(181)), 半径: 3.61
# Slice 66 - Region 1:
#   最大圆 - 圆心: (np.int64(111), np.int64(156)), 半径: 3.00
#   第二个圆 - 圆心: (np.int64(111), np.int64(156)), 半径: 3.00
#   第三个圆 - 圆心: (np.int64(111), np.int64(156)), 半径: 3.00
# Slice 66 - Region 2:
#   最大圆 - 圆心: (np.int64(116), np.int64(105)), 半径: 4.12
#   第二个圆 - 圆心: (np.int64(116), np.int64(105)), 半径: 4.12
#   第三个圆 - 圆心: (np.int64(116), np.int64(105)), 半径: 4.12
# Slice 66 - Region 3:
#   最大圆 - 圆心: (np.int64(202), np.int64(94)), 半径: 1.41
#   第二个圆 - 圆心: (np.int64(202), np.int64(94)), 半径: 1.41
#   第三个圆 - 圆心: (np.int64(202), np.int64(94)), 半径: 1.41
# Slice 66 - Region 4:
#   最大圆 - 圆心: (np.int64(233), np.int64(182)), 半径: 3.00
#   第二个圆 - 圆心: (np.int64(233), np.int64(182)), 半径: 3.00
#   第三个圆 - 圆心: (np.int64(233), np.int64(182)), 半径: 3.00
# Slice 67 - Region 1:
#   最大圆 - 圆心: (np.int64(111), np.int64(157)), 半径: 3.00
#   第二个圆 - 圆心: (np.int64(111), np.int64(157)), 半径: 3.00
#   第三个圆 - 圆心: (np.int64(111), np.int64(157)), 半径: 3.00
# Slice 67 - Region 2:
#   最大圆 - 圆心: (np.int64(116), np.int64(106)), 半径: 4.47
#   第二个圆 - 圆心: (np.int64(116), np.int64(106)), 半径: 4.47
#   第三个圆 - 圆心: (np.int64(116), np.int64(106)), 半径: 4.47
# Slice 67 - Region 3:
#   最大圆 - 圆心: (np.int64(201), np.int64(93)), 半径: 1.00
#   第二个圆 - 圆心: (np.int64(201), np.int64(93)), 半径: 1.00
#   第三个圆 - 圆心: (np.int64(201), np.int64(93)), 半径: 1.00
# Slice 67 - Region 4:
#   最大圆 - 圆心: (np.int64(234), np.int64(182)), 半径: 3.16
#   第二个圆 - 圆心: (np.int64(234), np.int64(182)), 半径: 3.16
#   第三个圆 - 圆心: (np.int64(234), np.int64(182)), 半径: 3.16
# Slice 68 - Region 1:
#   最大圆 - 圆心: (np.int64(110), np.int64(157)), 半径: 3.00
#   第二个圆 - 圆心: (np.int64(110), np.int64(157)), 半径: 3.00
#   第三个圆 - 圆心: (np.int64(110), np.int64(157)), 半径: 3.00
# Slice 68 - Region 2:
#   最大圆 - 圆心: (np.int64(116), np.int64(106)), 半径: 4.00
#   第二个圆 - 圆心: (np.int64(116), np.int64(106)), 半径: 4.00
#   第三个圆 - 圆心: (np.int64(116), np.int64(106)), 半径: 4.00
# Slice 68 - Region 3:
#   最大圆 - 圆心: (np.int64(201), np.int64(93)), 半径: 1.00
#   第二个圆 - 圆心: (np.int64(201), np.int64(93)), 半径: 1.00
#   第三个圆 - 圆心: (np.int64(201), np.int64(93)), 半径: 1.00
# Slice 68 - Region 4:
#   最大圆 - 圆心: (np.int64(234), np.int64(182)), 半径: 3.00
#   第二个圆 - 圆心: (np.int64(234), np.int64(182)), 半径: 3.00
#   第三个圆 - 圆心: (np.int64(234), np.int64(182)), 半径: 3.00
# Slice 69 - Region 1:
#   最大圆 - 圆心: (np.int64(110), np.int64(157)), 半径: 3.16
#   第二个圆 - 圆心: (np.int64(110), np.int64(157)), 半径: 3.16
#   第三个圆 - 圆心: (np.int64(110), np.int64(157)), 半径: 3.16
# Slice 69 - Region 2:
#   最大圆 - 圆心: (np.int64(116), np.int64(107)), 半径: 3.61
#   第二个圆 - 圆心: (np.int64(116), np.int64(107)), 半径: 3.61
#   第三个圆 - 圆心: (np.int64(116), np.int64(107)), 半径: 3.61
# Slice 69 - Region 3:
#   最大圆 - 圆心: (np.int64(201), np.int64(93)), 半径: 1.00
#   第二个圆 - 圆心: (np.int64(201), np.int64(93)), 半径: 1.00
#   第三个圆 - 圆心: (np.int64(201), np.int64(93)), 半径: 1.00
# Slice 69 - Region 4:
#   最大圆 - 圆心: (np.int64(234), np.int64(183)), 半径: 2.83
#   第二个圆 - 圆心: (np.int64(234), np.int64(183)), 半径: 2.83
#   第三个圆 - 圆心: (np.int64(234), np.int64(183)), 半径: 2.83
# Slice 70 - Region 1:
#   最大圆 - 圆心: (np.int64(110), np.int64(158)), 半径: 3.16
#   第二个圆 - 圆心: (np.int64(110), np.int64(158)), 半径: 3.16
#   第三个圆 - 圆心: (np.int64(110), np.int64(158)), 半径: 3.16
# Slice 70 - Region 2:
#   最大圆 - 圆心: (np.int64(119), np.int64(106)), 半径: 3.16
#   第二个圆 - 圆心: (np.int64(119), np.int64(106)), 半径: 3.16
#   第三个圆 - 圆心: (np.int64(119), np.int64(106)), 半径: 3.16
# Slice 70 - Region 3:
#   最大圆 - 圆心: (np.int64(203), np.int64(94)), 半径: 1.41
#   第二个圆 - 圆心: (np.int64(203), np.int64(94)), 半径: 1.41
#   第三个圆 - 圆心: (np.int64(203), np.int64(94)), 半径: 1.41
# Slice 70 - Region 4:
#   最大圆 - 圆心: (np.int64(235), np.int64(183)), 半径: 3.16
#   第二个圆 - 圆心: (np.int64(235), np.int64(183)), 半径: 3.16
#   第三个圆 - 圆心: (np.int64(235), np.int64(183)), 半径: 3.16
# Slice 71 - Region 1:
#   最大圆 - 圆心: (np.int64(110), np.int64(158)), 半径: 3.16
#   第二个圆 - 圆心: (np.int64(110), np.int64(158)), 半径: 3.16
#   第三个圆 - 圆心: (np.int64(110), np.int64(158)), 半径: 3.16
# Slice 71 - Region 2:
#   最大圆 - 圆心: (np.int64(120), np.int64(106)), 半径: 3.16
#   第二个圆 - 圆心: (np.int64(120), np.int64(106)), 半径: 3.16
#   第三个圆 - 圆心: (np.int64(120), np.int64(106)), 半径: 3.16
# Slice 71 - Region 3:
#   最大圆 - 圆心: (np.int64(201), np.int64(93)), 半径: 1.00
#   第二个圆 - 圆心: (np.int64(201), np.int64(93)), 半径: 1.00
#   第三个圆 - 圆心: (np.int64(201), np.int64(93)), 半径: 1.00
# Slice 71 - Region 4:
#   最大圆 - 圆心: (np.int64(235), np.int64(183)), 半径: 2.83
#   第二个圆 - 圆心: (np.int64(235), np.int64(183)), 半径: 2.83
#   第三个圆 - 圆心: (np.int64(235), np.int64(183)), 半径: 2.83
# Slice 72 - Region 1:
#   最大圆 - 圆心: (np.int64(109), np.int64(158)), 半径: 2.83
#   第二个圆 - 圆心: (np.int64(109), np.int64(158)), 半径: 2.83
#   第三个圆 - 圆心: (np.int64(109), np.int64(158)), 半径: 2.83
# Slice 72 - Region 2:
#   最大圆 - 圆心: (np.int64(119), np.int64(107)), 半径: 3.16
#   第二个圆 - 圆心: (np.int64(119), np.int64(107)), 半径: 3.16
#   第三个圆 - 圆心: (np.int64(119), np.int64(107)), 半径: 3.16
# Slice 72 - Region 3:
#   最大圆 - 圆心: (np.int64(201), np.int64(93)), 半径: 1.41
#   第二个圆 - 圆心: (np.int64(201), np.int64(93)), 半径: 1.41
#   第三个圆 - 圆心: (np.int64(201), np.int64(93)), 半径: 1.41
# Slice 72 - Region 4:
#   最大圆 - 圆心: (np.int64(235), np.int64(184)), 半径: 2.83
#   第二个圆 - 圆心: (np.int64(235), np.int64(184)), 半径: 2.83
#   第三个圆 - 圆心: (np.int64(235), np.int64(184)), 半径: 2.83
# Slice 73 - Region 1:
#   最大圆 - 圆心: (np.int64(109), np.int64(158)), 半径: 2.83
#   第二个圆 - 圆心: (np.int64(109), np.int64(158)), 半径: 2.83
#   第三个圆 - 圆心: (np.int64(109), np.int64(158)), 半径: 2.83
# Slice 73 - Region 2:
#   最大圆 - 圆心: (np.int64(121), np.int64(107)), 半径: 3.16
#   第二个圆 - 圆心: (np.int64(121), np.int64(107)), 半径: 3.16
#   第三个圆 - 圆心: (np.int64(121), np.int64(107)), 半径: 3.16
# Slice 73 - Region 3:
#   最大圆 - 圆心: (np.int64(201), np.int64(93)), 半径: 1.41
#   第二个圆 - 圆心: (np.int64(201), np.int64(93)), 半径: 1.41
#   第三个圆 - 圆心: (np.int64(201), np.int64(93)), 半径: 1.41
# Slice 73 - Region 4:
#   最大圆 - 圆心: (np.int64(236), np.int64(184)), 半径: 3.00
#   第二个圆 - 圆心: (np.int64(236), np.int64(184)), 半径: 3.00
#   第三个圆 - 圆心: (np.int64(236), np.int64(184)), 半径: 3.00
# Slice 74 - Region 1:
#   最大圆 - 圆心: (np.int64(109), np.int64(159)), 半径: 3.00
#   第二个圆 - 圆心: (np.int64(109), np.int64(159)), 半径: 3.00
#   第三个圆 - 圆心: (np.int64(109), np.int64(159)), 半径: 3.00
# Slice 74 - Region 2:
#   最大圆 - 圆心: (np.int64(120), np.int64(107)), 半径: 3.00
#   第二个圆 - 圆心: (np.int64(120), np.int64(107)), 半径: 3.00
#   第三个圆 - 圆心: (np.int64(120), np.int64(107)), 半径: 3.00
# Slice 74 - Region 3:
#   最大圆 - 圆心: (np.int64(203), np.int64(94)), 半径: 2.00
#   第二个圆 - 圆心: (np.int64(203), np.int64(94)), 半径: 2.00
#   第三个圆 - 圆心: (np.int64(203), np.int64(94)), 半径: 2.00
# Slice 74 - Region 4:
#   最大圆 - 圆心: (np.int64(236), np.int64(185)), 半径: 3.00
#   第二个圆 - 圆心: (np.int64(236), np.int64(185)), 半径: 3.00
#   第三个圆 - 圆心: (np.int64(236), np.int64(185)), 半径: 3.00
# Slice 75 - Region 1:
#   最大圆 - 圆心: (np.int64(109), np.int64(159)), 半径: 3.00
#   第二个圆 - 圆心: (np.int64(109), np.int64(159)), 半径: 3.00
#   第三个圆 - 圆心: (np.int64(109), np.int64(159)), 半径: 3.00
# Slice 75 - Region 2:
#   最大圆 - 圆心: (np.int64(121), np.int64(107)), 半径: 3.00
#   第二个圆 - 圆心: (np.int64(121), np.int64(107)), 半径: 3.00
#   第三个圆 - 圆心: (np.int64(121), np.int64(107)), 半径: 3.00
# Slice 75 - Region 3:
#   最大圆 - 圆心: (np.int64(202), np.int64(93)), 半径: 2.00
#   第二个圆 - 圆心: (np.int64(202), np.int64(93)), 半径: 2.00
#   第三个圆 - 圆心: (np.int64(202), np.int64(93)), 半径: 2.00
# Slice 75 - Region 4:
#   最大圆 - 圆心: (np.int64(236), np.int64(185)), 半径: 3.00
#   第二个圆 - 圆心: (np.int64(236), np.int64(185)), 半径: 3.00
#   第三个圆 - 圆心: (np.int64(236), np.int64(185)), 半径: 3.00
# Slice 76 - Region 1:
#   最大圆 - 圆心: (np.int64(109), np.int64(159)), 半径: 3.00
#   第二个圆 - 圆心: (np.int64(109), np.int64(159)), 半径: 3.00
#   第三个圆 - 圆心: (np.int64(109), np.int64(159)), 半径: 3.00
# Slice 76 - Region 2:
#   最大圆 - 圆心: (np.int64(122), np.int64(107)), 半径: 3.00
#   第二个圆 - 圆心: (np.int64(122), np.int64(107)), 半径: 3.00
#   第三个圆 - 圆心: (np.int64(122), np.int64(107)), 半径: 3.00
# Slice 76 - Region 3:
#   最大圆 - 圆心: (np.int64(201), np.int64(92)), 半径: 2.00
#   第二个圆 - 圆心: (np.int64(201), np.int64(92)), 半径: 2.00
#   第三个圆 - 圆心: (np.int64(201), np.int64(92)), 半径: 2.00
# Slice 76 - Region 4:
#   最大圆 - 圆心: (np.int64(237), np.int64(185)), 半径: 3.00
#   第二个圆 - 圆心: (np.int64(237), np.int64(185)), 半径: 3.00
#   第三个圆 - 圆心: (np.int64(237), np.int64(185)), 半径: 3.00
# Slice 77 - Region 1:
#   最大圆 - 圆心: (np.int64(109), np.int64(160)), 半径: 3.00
#   第二个圆 - 圆心: (np.int64(109), np.int64(160)), 半径: 3.00
#   第三个圆 - 圆心: (np.int64(109), np.int64(160)), 半径: 3.00
# Slice 77 - Region 2:
#   最大圆 - 圆心: (np.int64(122), np.int64(108)), 半径: 3.00
#   第二个圆 - 圆心: (np.int64(122), np.int64(108)), 半径: 3.00
#   第三个圆 - 圆心: (np.int64(122), np.int64(108)), 半径: 3.00
# Slice 77 - Region 3:
#   最大圆 - 圆心: (np.int64(202), np.int64(92)), 半径: 2.00
#   第二个圆 - 圆心: (np.int64(202), np.int64(92)), 半径: 2.00
#   第三个圆 - 圆心: (np.int64(202), np.int64(92)), 半径: 2.00
# Slice 77 - Region 4:
#   最大圆 - 圆心: (np.int64(237), np.int64(186)), 半径: 3.00
#   第二个圆 - 圆心: (np.int64(237), np.int64(186)), 半径: 3.00
#   第三个圆 - 圆心: (np.int64(237), np.int64(186)), 半径: 3.00
# Slice 78 - Region 1:
#   最大圆 - 圆心: (np.int64(109), np.int64(160)), 半径: 3.00
#   第二个圆 - 圆心: (np.int64(109), np.int64(160)), 半径: 3.00
#   第三个圆 - 圆心: (np.int64(109), np.int64(160)), 半径: 3.00
# Slice 78 - Region 2:
#   最大圆 - 圆心: (np.int64(121), np.int64(108)), 半径: 2.83
#   第二个圆 - 圆心: (np.int64(121), np.int64(108)), 半径: 2.83
#   第三个圆 - 圆心: (np.int64(121), np.int64(108)), 半径: 2.83
# Slice 78 - Region 3:
#   最大圆 - 圆心: (np.int64(202), np.int64(92)), 半径: 2.24
#   第二个圆 - 圆心: (np.int64(202), np.int64(92)), 半径: 2.24
#   第三个圆 - 圆心: (np.int64(202), np.int64(92)), 半径: 2.24
# Slice 78 - Region 4:
#   最大圆 - 圆心: (np.int64(237), np.int64(186)), 半径: 2.83
#   第二个圆 - 圆心: (np.int64(237), np.int64(186)), 半径: 2.83
#   第三个圆 - 圆心: (np.int64(237), np.int64(186)), 半径: 2.83
# Slice 79 - Region 1:
#   最大圆 - 圆心: (np.int64(109), np.int64(160)), 半径: 3.16
#   第二个圆 - 圆心: (np.int64(109), np.int64(160)), 半径: 3.16
#   第三个圆 - 圆心: (np.int64(109), np.int64(160)), 半径: 3.16
# Slice 79 - Region 2:
#   最大圆 - 圆心: (np.int64(121), np.int64(109)), 半径: 2.83
#   第二个圆 - 圆心: (np.int64(121), np.int64(109)), 半径: 2.83
#   第三个圆 - 圆心: (np.int64(121), np.int64(109)), 半径: 2.83
# Slice 79 - Region 3:
#   最大圆 - 圆心: (np.int64(202), np.int64(92)), 半径: 2.24
#   第二个圆 - 圆心: (np.int64(202), np.int64(92)), 半径: 2.24
#   第三个圆 - 圆心: (np.int64(202), np.int64(92)), 半径: 2.24
# Slice 79 - Region 4:
#   最大圆 - 圆心: (np.int64(237), np.int64(187)), 半径: 3.00
#   第二个圆 - 圆心: (np.int64(237), np.int64(187)), 半径: 3.00
#   第三个圆 - 圆心: (np.int64(237), np.int64(187)), 半径: 3.00
# Slice 80 - Region 1:
#   最大圆 - 圆心: (np.int64(108), np.int64(160)), 半径: 2.83
#   第二个圆 - 圆心: (np.int64(108), np.int64(160)), 半径: 2.83
#   第三个圆 - 圆心: (np.int64(108), np.int64(160)), 半径: 2.83
# Slice 80 - Region 2:
#   最大圆 - 圆心: (np.int64(121), np.int64(109)), 半径: 2.83
#   第二个圆 - 圆心: (np.int64(121), np.int64(109)), 半径: 2.83
#   第三个圆 - 圆心: (np.int64(121), np.int64(109)), 半径: 2.83
# Slice 80 - Region 3:
#   最大圆 - 圆心: (np.int64(202), np.int64(91)), 半径: 2.24
#   第二个圆 - 圆心: (np.int64(202), np.int64(91)), 半径: 2.24
#   第三个圆 - 圆心: (np.int64(202), np.int64(91)), 半径: 2.24
# Slice 80 - Region 4:
#   最大圆 - 圆心: (np.int64(238), np.int64(187)), 半径: 3.16
#   第二个圆 - 圆心: (np.int64(238), np.int64(187)), 半径: 3.16
#   第三个圆 - 圆心: (np.int64(238), np.int64(187)), 半径: 3.16
# Slice 81 - Region 1:
#   最大圆 - 圆心: (np.int64(108), np.int64(160)), 半径: 2.83
#   第二个圆 - 圆心: (np.int64(108), np.int64(160)), 半径: 2.83
#   第三个圆 - 圆心: (np.int64(108), np.int64(160)), 半径: 2.83
# Slice 81 - Region 2:
#   最大圆 - 圆心: (np.int64(122), np.int64(108)), 半径: 2.83
#   第二个圆 - 圆心: (np.int64(122), np.int64(108)), 半径: 2.83
#   第三个圆 - 圆心: (np.int64(122), np.int64(108)), 半径: 2.83
# Slice 81 - Region 3:
#   最大圆 - 圆心: (np.int64(202), np.int64(91)), 半径: 2.83
#   第二个圆 - 圆心: (np.int64(202), np.int64(91)), 半径: 2.83
#   第三个圆 - 圆心: (np.int64(202), np.int64(91)), 半径: 2.83
# Slice 81 - Region 4:
#   最大圆 - 圆心: (np.int64(238), np.int64(188)), 半径: 3.00
#   第二个圆 - 圆心: (np.int64(238), np.int64(188)), 半径: 3.00
#   第三个圆 - 圆心: (np.int64(238), np.int64(188)), 半径: 3.00
# Slice 82 - Region 1:
#   最大圆 - 圆心: (np.int64(108), np.int64(161)), 半径: 2.83
#   第二个圆 - 圆心: (np.int64(108), np.int64(161)), 半径: 2.83
#   第三个圆 - 圆心: (np.int64(108), np.int64(161)), 半径: 2.83
# Slice 82 - Region 2:
#   最大圆 - 圆心: (np.int64(122), np.int64(108)), 半径: 2.24
#   第二个圆 - 圆心: (np.int64(122), np.int64(108)), 半径: 2.24
#   第三个圆 - 圆心: (np.int64(122), np.int64(108)), 半径: 2.24
# Slice 82 - Region 3:
#   最大圆 - 圆心: (np.int64(202), np.int64(91)), 半径: 2.83
#   第二个圆 - 圆心: (np.int64(202), np.int64(91)), 半径: 2.83
#   第三个圆 - 圆心: (np.int64(202), np.int64(91)), 半径: 2.83
# Slice 82 - Region 4:
#   最大圆 - 圆心: (np.int64(238), np.int64(188)), 半径: 2.83
#   第二个圆 - 圆心: (np.int64(238), np.int64(188)), 半径: 2.83
#   第三个圆 - 圆心: (np.int64(238), np.int64(188)), 半径: 2.83
# Slice 83 - Region 1:
#   最大圆 - 圆心: (np.int64(109), np.int64(161)), 半径: 3.16
#   第二个圆 - 圆心: (np.int64(109), np.int64(161)), 半径: 3.16
#   第三个圆 - 圆心: (np.int64(109), np.int64(161)), 半径: 3.16
# Slice 83 - Region 2:
#   最大圆 - 圆心: (np.int64(122), np.int64(108)), 半径: 2.24
#   第二个圆 - 圆心: (np.int64(122), np.int64(108)), 半径: 2.24
#   第三个圆 - 圆心: (np.int64(122), np.int64(108)), 半径: 2.24
# Slice 83 - Region 3:
#   最大圆 - 圆心: (np.int64(202), np.int64(90)), 半径: 2.83
#   第二个圆 - 圆心: (np.int64(202), np.int64(90)), 半径: 2.83
#   第三个圆 - 圆心: (np.int64(202), np.int64(90)), 半径: 2.83
# Slice 83 - Region 4:
#   最大圆 - 圆心: (np.int64(238), np.int64(189)), 半径: 3.00
#   第二个圆 - 圆心: (np.int64(238), np.int64(189)), 半径: 3.00
#   第三个圆 - 圆心: (np.int64(238), np.int64(189)), 半径: 3.00
# Slice 84 - Region 1:
#   最大圆 - 圆心: (np.int64(109), np.int64(161)), 半径: 3.00
#   第二个圆 - 圆心: (np.int64(109), np.int64(161)), 半径: 3.00
#   第三个圆 - 圆心: (np.int64(109), np.int64(161)), 半径: 3.00
# Slice 84 - Region 2:
#   最大圆 - 圆心: (np.int64(122), np.int64(109)), 半径: 2.24
#   第二个圆 - 圆心: (np.int64(122), np.int64(109)), 半径: 2.24
#   第三个圆 - 圆心: (np.int64(122), np.int64(109)), 半径: 2.24
# Slice 84 - Region 3:
#   最大圆 - 圆心: (np.int64(203), np.int64(90)), 半径: 2.83
#   第二个圆 - 圆心: (np.int64(203), np.int64(90)), 半径: 2.83
#   第三个圆 - 圆心: (np.int64(203), np.int64(90)), 半径: 2.83
# Slice 84 - Region 4:
#   最大圆 - 圆心: (np.int64(239), np.int64(189)), 半径: 3.16
#   第二个圆 - 圆心: (np.int64(239), np.int64(189)), 半径: 3.16
#   第三个圆 - 圆心: (np.int64(239), np.int64(189)), 半径: 3.16
# Slice 85 - Region 1:
#   最大圆 - 圆心: (np.int64(109), np.int64(161)), 半径: 2.83
#   第二个圆 - 圆心: (np.int64(109), np.int64(161)), 半径: 2.83
#   第三个圆 - 圆心: (np.int64(109), np.int64(161)), 半径: 2.83
# Slice 85 - Region 2:
#   最大圆 - 圆心: (np.int64(123), np.int64(108)), 半径: 2.24
#   第二个圆 - 圆心: (np.int64(123), np.int64(108)), 半径: 2.24
#   第三个圆 - 圆心: (np.int64(123), np.int64(108)), 半径: 2.24
# Slice 85 - Region 3:
#   最大圆 - 圆心: (np.int64(203), np.int64(90)), 半径: 2.83
#   第二个圆 - 圆心: (np.int64(203), np.int64(90)), 半径: 2.83
#   第三个圆 - 圆心: (np.int64(203), np.int64(90)), 半径: 2.83
# Slice 85 - Region 4:
#   最大圆 - 圆心: (np.int64(239), np.int64(189)), 半径: 2.83
#   第二个圆 - 圆心: (np.int64(239), np.int64(189)), 半径: 2.83
#   第三个圆 - 圆心: (np.int64(239), np.int64(189)), 半径: 2.83
# Slice 86 - Region 1:
#   最大圆 - 圆心: (np.int64(109), np.int64(162)), 半径: 3.00
#   第二个圆 - 圆心: (np.int64(109), np.int64(162)), 半径: 3.00
#   第三个圆 - 圆心: (np.int64(109), np.int64(162)), 半径: 3.00
# Slice 86 - Region 2:
#   最大圆 - 圆心: (np.int64(123), np.int64(108)), 半径: 2.24
#   第二个圆 - 圆心: (np.int64(123), np.int64(108)), 半径: 2.24
#   第三个圆 - 圆心: (np.int64(123), np.int64(108)), 半径: 2.24
# Slice 86 - Region 3:
#   最大圆 - 圆心: (np.int64(203), np.int64(90)), 半径: 2.83
#   第二个圆 - 圆心: (np.int64(203), np.int64(90)), 半径: 2.83
#   第三个圆 - 圆心: (np.int64(203), np.int64(90)), 半径: 2.83
# Slice 86 - Region 4:
#   最大圆 - 圆心: (np.int64(240), np.int64(189)), 半径: 3.00
#   第二个圆 - 圆心: (np.int64(240), np.int64(189)), 半径: 3.00
#   第三个圆 - 圆心: (np.int64(240), np.int64(189)), 半径: 3.00
# Slice 87 - Region 1:
#   最大圆 - 圆心: (np.int64(108), np.int64(163)), 半径: 2.83
#   第二个圆 - 圆心: (np.int64(108), np.int64(163)), 半径: 2.83
#   第三个圆 - 圆心: (np.int64(108), np.int64(163)), 半径: 2.83
# Slice 87 - Region 2:
#   最大圆 - 圆心: (np.int64(123), np.int64(108)), 半径: 2.24
#   第二个圆 - 圆心: (np.int64(123), np.int64(108)), 半径: 2.24
#   第三个圆 - 圆心: (np.int64(123), np.int64(108)), 半径: 2.24
# Slice 87 - Region 3:
#   最大圆 - 圆心: (np.int64(204), np.int64(91)), 半径: 2.83
#   第二个圆 - 圆心: (np.int64(204), np.int64(91)), 半径: 2.83
#   第三个圆 - 圆心: (np.int64(204), np.int64(91)), 半径: 2.83
# Slice 87 - Region 4:
#   最大圆 - 圆心: (np.int64(240), np.int64(190)), 半径: 3.00
#   第二个圆 - 圆心: (np.int64(240), np.int64(190)), 半径: 3.00
#   第三个圆 - 圆心: (np.int64(240), np.int64(190)), 半径: 3.00
# Slice 88 - Region 1:
#   最大圆 - 圆心: (np.int64(108), np.int64(163)), 半径: 2.83
#   第二个圆 - 圆心: (np.int64(108), np.int64(163)), 半径: 2.83
#   第三个圆 - 圆心: (np.int64(108), np.int64(163)), 半径: 2.83
# Slice 88 - Region 2:
#   最大圆 - 圆心: (np.int64(123), np.int64(108)), 半径: 2.24
#   第二个圆 - 圆心: (np.int64(123), np.int64(108)), 半径: 2.24
#   第三个圆 - 圆心: (np.int64(123), np.int64(108)), 半径: 2.24
# Slice 88 - Region 3:
#   最大圆 - 圆心: (np.int64(204), np.int64(90)), 半径: 2.83
#   第二个圆 - 圆心: (np.int64(204), np.int64(90)), 半径: 2.83
#   第三个圆 - 圆心: (np.int64(204), np.int64(90)), 半径: 2.83
# Slice 88 - Region 4:
#   最大圆 - 圆心: (np.int64(240), np.int64(190)), 半径: 2.83
#   第二个圆 - 圆心: (np.int64(240), np.int64(190)), 半径: 2.83
#   第三个圆 - 圆心: (np.int64(240), np.int64(190)), 半径: 2.83
# ...
#   Layer 54: Point (111.22620489968999, 152.79622930547455)
#   Layer 55: Point (111.23670331499473, 153.04910794774057)
#   Layer 56: Point (111.2408067228168, 153.3090416488896)
#   Layer 57: Point (111.23864482015865, 153.5757525821137)
#   Layer 58: Point (111.23034730402294, 153.84896292060517)
#   Layer 59: Point (111.21604387141221, 154.12839483755613)
#   Layer 60: Point (111.19586421932891, 154.4137705061587)
#   Layer 61: Point (111.16993804477575, 154.70481209960514)
#   Layer 62: Point (111.13839504475519, 155.0012417910876)
#   Layer 63: Point (111.10136491626974, 155.30278175379817)
#   Layer 64: Point (111.05897735632206, 155.6091541609291)
#   Layer 65: Point (111.01136206191465, 155.92008118567261)
#   Layer 66: Point (110.95864873005009, 156.23528500122077)
#   Layer 67: Point (110.90096705773088, 156.5544877807658)
#   Layer 68: Point (110.83844674195961, 156.8774116974999)
#   Layer 69: Point (110.77121747973887, 157.2037789246152)
#   Layer 70: Point (110.69940896807115, 157.53331163530385)
#   Layer 71: Point (110.62315090395904, 157.86573200275808)
#   Layer 72: Point (110.54257298440511, 158.20076220017003)
#   Layer 73: Point (110.45780490641184, 158.5381244007319)
#   Layer 288: Point (97.75422321662937, 184.5497846653635)
#   Layer 289: Point (97.88801602416439, 184.51245265121173)
#   Layer 290: Point (98.02385096291685, 184.47040119496268)
#   Layer 291: Point (98.16172730113529, 184.42349575455532)
#   Layer 292: Point (98.30164430706819, 184.3716017879287)
#   Layer 293: Point (98.44360124896411, 184.31458475302193)
#   Layer 294: Point (98.58759739507153, 184.25231010777404)
#   Layer 295: Point (98.73363201363901, 184.1846433101241)
#   Layer 296: Point (98.88170437291507, 184.11144981801124)
#   Layer 297: Point (99.0318137411482, 184.03259508937444)
#   Layer 298: Point (99.18395938658695, 183.94794458215281)
#   Layer 299: Point (99.33814057747985, 183.85736375428544)
#   Layer 300: Point (99.4943565820754, 183.76071806371135)
#   Layer 301: Point (99.65260666862216, 183.65787296836962)
#   Layer 302: Point (99.81289010536861, 183.5486939261993)
#   Layer 303: Point (99.9752061605633, 183.43304639513948)
#   Layer 304: Point (100.13955410245474, 183.31079583312925)
#   Layer 305: Point (100.30593319929147, 183.1818076981076)
#   Layer 306: Point (100.474342719322, 183.04594744801366)
#   Layer 307: Point (100.64478193079485, 182.90308054078645)
#   Layer 308: Point (100.81725010195855, 182.7530724343651)
#   Layer 309: Point (100.99174650106163, 182.59578858668866)
#   Layer 310: Point (101.16827039635258, 182.43109445569613)
#   Layer 311: Point (101.34682105607997, 182.25885549932664)
#   Layer 312: Point (101.52739774849229, 182.07893717551923)
#   Layer 313: Point (101.70999974183809, 181.89120494221297)
#   Layer 314: Point (101.89462630436589, 181.69552425734696)
#   Layer 315: Point (102.08127670432417, 181.4917605788602)
#   Layer 316: Point (102.2699502099615, 181.27977936469182)
#   Layer 317: Point (102.46064608952636, 181.05944607278084)
#   Layer 318: Point (102.65336361126732, 180.8306261610663)
#   Layer 319: Point (102.84810204343289, 180.5931850874874)
#   Layer 320: Point (103.04486065427156, 180.34698830998306)
#   Layer 321: Point (103.24363871203191, 180.0919012864924)
#
#
# 生成三维表面网格
# 三维表面网格生成完毕.
# 生成中心线的三维表面网格
# 中心线的三维表面网格生成完毕.
# 可视化三维模型和中心线
# 2024-10-20 18:03:28.998 python[60679:8640533] +[IMKClient subclass]: chose IMKClient_Legacy
# 2024-10-20 18:03:28.998 python[60679:8640533] +[IMKInputSession subclass]: chose IMKInputSession_Legacy

# %%
import nibabel as nib
import numpy as np
from functions import search_circles, find_lines, process_central_lines, process_b_spline_central_lines, visualize_lines
from skimage import morphology, measure
import open3d as o3d
import matplotlib.pyplot as plt  
import matplotlib.cm as cm  

# 文件路径
#nifti_file = 'Cshape/5475-4_Canal.nii' 
nifti_file = 'qulv/5530-3/5530-3ori_canal.nii'
#nifti_file = 'all_c_shape/canal-before.nii'
img = nib.load(nifti_file)
data = img.get_fdata()
num_slices = data.shape[2]  

# 初始化三维二值掩模
binary_volume = np.zeros_like(data, dtype=bool)

# 初始化中心线三维二值掩模
central_line_volume = np.zeros_like(data, dtype=bool)

# 找到最大圆
circles_info, binary_volume = search_circles(data, binary_volume)

# 打印所有区域的圆信息
for info in circles_info:
    slice_idx = info['slice']
    region_label = info['region_label']
    max_c = info['max_circle']
    sec_c = info['second_circle']
    thi_c = info['third_circle']
    print(f"Slice {slice_idx} - Region {region_label}:")
    print(f"  最大圆 - 圆心: {max_c['center']}, 半径: {max_c['radius']:.2f}")
    print(f"  第二个圆 - 圆心: {sec_c['center']}, 半径: {sec_c['radius']:.2f}")
    print(f"  第三个圆 - 圆心: {thi_c['center']}, 半径: {thi_c['radius']:.2f}")

# 允许的中心线两层之间最大距离
point_max_dist = 5

# 找中心线
central_lines = find_lines(circles_info, point_max_dist)

# 处理中心线，选择最长的四条并进行平滑
#central_smooth_line = process_central_lines(central_lines, window_size=9, top_n=4)
central_smooth_line = process_b_spline_central_lines(central_lines, smooth_factor=200, top_n=4)

# 打印结果验证
for line_name, smooth_line in central_smooth_line.items():
    print(f"{line_name}:")
    for point in smooth_line:
        print(f"  Layer {point['layer']}: Point {point['point']}")
    print("\n")

# 计算曲率
def compute_curvature(points):
    """
    计算一条曲线的曲率。
    :param points: 曲线上的点列表，每个点为 [y, x, z]
    :return: 曲率列表，与点数量相同
    """
    curvatures = []
    for i in range(1, len(points)-1):
        p_prev = np.array(points[i-1])
        p_curr = np.array(points[i])
        p_next = np.array(points[i+1])

        v1 = p_curr - p_prev
        v2 = p_next - p_curr

        norm_v1 = np.linalg.norm(v1)
        norm_v2 = np.linalg.norm(v2)

        if norm_v1 == 0 or norm_v2 == 0:
            curvature = 0
        else:
            cos_theta = np.dot(v1, v2) / (norm_v1 * norm_v2)
            cos_theta = np.clip(cos_theta, -1.0, 1.0)  
            theta = np.arccos(cos_theta)
            curvature = theta / norm_v1  

        curvatures.append(curvature)

    # 对于首尾点，使用邻近点的曲率
    if len(curvatures) > 0:
        curvatures = [curvatures[0]] + curvatures + [curvatures[-1]]
    else:
        curvatures = [0] * len(points)

    return curvatures

# 映射曲率到颜色
def map_curvature_to_color(curvatures, colormap_name='jet'):
    """
    将曲率值映射到颜色。
    :param curvatures: 曲率列表
    :param colormap_name: 使用的matplotlib色图
    :return: 颜色列表，每个颜色为 [R, G, B]
    """
    cmap = cm.get_cmap(colormap_name)
    norm = plt.Normalize(vmin=min(curvatures), vmax=max(curvatures))
    colors = cmap(norm(curvatures))[:, :3]  # 去除alpha通道
    return colors.tolist()

# 创建带有曲率颜色的线集
curvature_line_sets = []
for line_name, smooth_line in central_smooth_line.items():
    points = []
    for point in smooth_line:
        y, x = point['point']
        z = point['layer']
        # 将索引转换为实际坐标，根据需要调整比例
        points.append([y+30, x, z])  

    curvatures = compute_curvature(points)
    colors = map_curvature_to_color(curvatures)

    # 创建线段（每两个相邻点之间一条线）
    lines = [[i, i + 1] for i in range(len(points) - 1)]
    # 对应每条线段分配一个颜色，取线段起点的颜色
    line_colors = [colors[i] for i in range(len(lines))]

    # 创建 Open3D 的 LineSet
    line_set = o3d.geometry.LineSet()
    line_set.points = o3d.utility.Vector3dVector(points)
    line_set.lines = o3d.utility.Vector2iVector(lines)
    line_set.colors = o3d.utility.Vector3dVector(line_colors)

    curvature_line_sets.append(line_set)

# 调用可视化函数
# visualize_lines(central_lines, central_smooth_line, num_samples=10)

# 将平滑后的中心线点转换为3D坐标，并在 central_line_volume 中设置相应的 voxels
for line_name, points in central_smooth_line.items():
    for point in points:
        y, x = point['point']
        z = point['layer']
        # 转换为整数索引
        try:
            y_int = int(round(y))
            x_int = int(round(x))
            z_int = int(z)
        except:
            x_int = -1
            y_int = -1
            z_int = -1
        # 边界检查
        if (0 <= y_int < data.shape[0] and
            0 <= x_int < data.shape[1] and
            0 <= z_int < data.shape[2]):
            central_line_volume[y_int, x_int, z_int] = True
        else:
            print(f"警告: 点 ({y_int}, {x_int}, {z_int}) 超出范围，未被添加到 central_line_volume。")

# 增强中心线的可视化（膨胀操作）
central_line_volume = morphology.binary_dilation(central_line_volume, morphology.ball(1))

# 生成三维表面网格
print("生成三维表面网格")
verts, faces, normals, values = measure.marching_cubes(binary_volume, level=0.5)
mesh_model = o3d.geometry.TriangleMesh()
mesh_model.vertices = o3d.utility.Vector3dVector(verts)
mesh_model.triangles = o3d.utility.Vector3iVector(faces)
mesh_model.compute_vertex_normals()
mesh_model.paint_uniform_color([0.7, 0.7, 0.7])  
print("三维表面网格生成完毕.")

# 生成中心线的三维表面网格
print("生成中心线的三维表面网格")
verts_line, faces_line, normals_line, values_line = measure.marching_cubes(central_line_volume, level=0.5)
mesh_lines = o3d.geometry.TriangleMesh()
mesh_lines.vertices = o3d.utility.Vector3dVector(verts_line)
mesh_lines.triangles = o3d.utility.Vector3iVector(faces_line)
mesh_lines.compute_vertex_normals()
mesh_lines.paint_uniform_color([1, 0, 0])  #红色
print("中心线的三维表面网格生成完毕.")

geometries = [mesh_model, mesh_lines]
#geometries = [mesh_model]

# 新增部分：添加带有曲率颜色的线集到几何体列表
geometries.extend(curvature_line_sets)

# 可视化
print("可视化三维模型和中心线")
o3d.visualization.draw_geometries(
    geometries,
    window_name='3D Model with Central Lines and Curvature',
    width=800,
    height=600,
    left=50,
    top=50,
    point_show_normal=False
)
# Out:
# Slice 0: 未检测到根管区域。
# Slice 1: 未检测到根管区域。
# Slice 2: 未检测到根管区域。
# Slice 3: 未检测到根管区域。
# Slice 4: 未检测到根管区域。
# Slice 5: 未检测到根管区域。
# Slice 6: 未检测到根管区域。
# Slice 7: 未检测到根管区域。
# Slice 8: 未检测到根管区域。
# Slice 9: 未检测到根管区域。
# Slice 10: 未检测到根管区域。
# Slice 11: 未检测到根管区域。
# Slice 12: 未检测到根管区域。
# Slice 13: 未检测到根管区域。
# Slice 14: 未检测到根管区域。
# Slice 15: 未检测到根管区域。
# Slice 16: 未检测到根管区域。
# Slice 17: 未检测到根管区域。
# Slice 582: 未检测到根管区域。
# Slice 583: 未检测到根管区域。
# Slice 584: 未检测到根管区域。
# Slice 585: 未检测到根管区域。
# Slice 586: 未检测到根管区域。
# Slice 587: 未检测到根管区域。
# Slice 588: 未检测到根管区域。
# Slice 589: 未检测到根管区域。
# Slice 590: 未检测到根管区域。
# Slice 591: 未检测到根管区域。
# Slice 592: 未检测到根管区域。
# Slice 593: 未检测到根管区域。
# Slice 594: 未检测到根管区域。
# Slice 595: 未检测到根管区域。
# Slice 596: 未检测到根管区域。
# Slice 597: 未检测到根管区域。
# Slice 598: 未检测到根管区域。
# Slice 599: 未检测到根管区域。
# Slice 600: 未检测到根管区域。
# Slice 601: 未检测到根管区域。
# Slice 602: 未检测到根管区域。
# Slice 603: 未检测到根管区域。
# Slice 604: 未检测到根管区域。
# Slice 605: 未检测到根管区域。
# Slice 606: 未检测到根管区域。
# Slice 607: 未检测到根管区域。
# Slice 608: 未检测到根管区域。
# Slice 609: 未检测到根管区域。
# Slice 610: 未检测到根管区域。
# Slice 611: 未检测到根管区域。
# Slice 612: 未检测到根管区域。
# Slice 613: 未检测到根管区域。
# Slice 614: 未检测到根管区域。
# Slice 615: 未检测到根管区域。
# Slice 616: 未检测到根管区域。
# Slice 617: 未检测到根管区域。
# Slice 618: 未检测到根管区域。
# Slice 619: 未检测到根管区域。
# Slice 620: 未检测到根管区域。
# Slice 621: 未检测到根管区域。
# Slice 622: 未检测到根管区域。
# Slice 623: 未检测到根管区域。
# Slice 624: 未检测到根管区域。
# Slice 625: 未检测到根管区域。
# Slice 626: 未检测到根管区域。
# Slice 627: 未检测到根管区域。
# Slice 628: 未检测到根管区域。
# Slice 629: 未检测到根管区域。
# Slice 630: 未检测到根管区域。
# Slice 631: 未检测到根管区域。
# Slice 632: 未检测到根管区域。
# Slice 633: 未检测到根管区域。
# Slice 634: 未检测到根管区域。
# Slice 635: 未检测到根管区域。
# Slice 636: 未检测到根管区域。
# Slice 637: 未检测到根管区域。
# Slice 638: 未检测到根管区域。
# Slice 639: 未检测到根管区域。
# Slice 640: 未检测到根管区域。
# Slice 641: 未检测到根管区域。
# Slice 642: 未检测到根管区域。
# Slice 643: 未检测到根管区域。
# Slice 644: 未检测到根管区域。
# Slice 645: 未检测到根管区域。
# Slice 646: 未检测到根管区域。
# Slice 647: 未检测到根管区域。
# Slice 648: 未检测到根管区域。
# Slice 649: 未检测到根管区域。
# Slice 650: 未检测到根管区域。
# Slice 651: 未检测到根管区域。
# Slice 652: 未检测到根管区域。
# Slice 653: 未检测到根管区域。
# Slice 654: 未检测到根管区域。
# Slice 655: 未检测到根管区域。
# Slice 656: 未检测到根管区域。
# Slice 657: 未检测到根管区域。
# Slice 658: 未检测到根管区域。
# Slice 659: 未检测到根管区域。
# Slice 660: 未检测到根管区域。
# Slice 661: 未检测到根管区域。
# Slice 662: 未检测到根管区域。
# Slice 663: 未检测到根管区域。
# Slice 664: 未检测到根管区域。
# Slice 665: 未检测到根管区域。
# Slice 666: 未检测到根管区域。
# Slice 667: 未检测到根管区域。
# Slice 668: 未检测到根管区域。
# Slice 669: 未检测到根管区域。
# Slice 670: 未检测到根管区域。
# Slice 671: 未检测到根管区域。
# Slice 672: 未检测到根管区域。
# Slice 673: 未检测到根管区域。
# Slice 674: 未检测到根管区域。
# Slice 675: 未检测到根管区域。
# Slice 676: 未检测到根管区域。
# Slice 677: 未检测到根管区域。
# Slice 678: 未检测到根管区域。
# Slice 679: 未检测到根管区域。
# Slice 680: 未检测到根管区域。
# Slice 681: 未检测到根管区域。
# Slice 682: 未检测到根管区域。
# Slice 683: 未检测到根管区域。
# Slice 684: 未检测到根管区域。
# Slice 685: 未检测到根管区域。
# Slice 686: 未检测到根管区域。
# Slice 687: 未检测到根管区域。
# Slice 688: 未检测到根管区域。
# Slice 689: 未检测到根管区域。
# Slice 690: 未检测到根管区域。
# Slice 691: 未检测到根管区域。
# Slice 692: 未检测到根管区域。
# Slice 18 - Region 1:
#   最大圆 - 圆心: (np.int64(105), np.int64(152)), 半径: 1.00
#   第二个圆 - 圆心: (np.int64(105), np.int64(152)), 半径: 1.00
#   第三个圆 - 圆心: (np.int64(105), np.int64(152)), 半径: 1.00
# Slice 19 - Region 1:
#   最大圆 - 圆心: (np.int64(105), np.int64(152)), 半径: 2.24
#   第二个圆 - 圆心: (np.int64(105), np.int64(152)), 半径: 2.24
#   第三个圆 - 圆心: (np.int64(105), np.int64(152)), 半径: 2.24
# Slice 20 - Region 1:
#   最大圆 - 圆心: (np.int64(105), np.int64(150)), 半径: 3.16
#   第二个圆 - 圆心: (np.int64(105), np.int64(150)), 半径: 3.16
#   第三个圆 - 圆心: (np.int64(105), np.int64(150)), 半径: 3.16
# Slice 21 - Region 1:
#   最大圆 - 圆心: (np.int64(104), np.int64(150)), 半径: 4.47
#   第二个圆 - 圆心: (np.int64(104), np.int64(150)), 半径: 4.47
#   第三个圆 - 圆心: (np.int64(104), np.int64(150)), 半径: 4.47
# Slice 22 - Region 1:
#   最大圆 - 圆心: (np.int64(103), np.int64(150)), 半径: 5.00
#   第二个圆 - 圆心: (np.int64(103), np.int64(150)), 半径: 5.00
#   第三个圆 - 圆心: (np.int64(103), np.int64(150)), 半径: 5.00
# Slice 23 - Region 1:
#   最大圆 - 圆心: (np.int64(103), np.int64(150)), 半径: 5.00
#   第二个圆 - 圆心: (np.int64(103), np.int64(150)), 半径: 5.00
#   第三个圆 - 圆心: (np.int64(103), np.int64(150)), 半径: 5.00
# Slice 24 - Region 1:
#   最大圆 - 圆心: (np.int64(104), np.int64(150)), 半径: 5.00
#   第二个圆 - 圆心: (np.int64(104), np.int64(150)), 半径: 5.00
#   第三个圆 - 圆心: (np.int64(104), np.int64(150)), 半径: 5.00
# Slice 24 - Region 2:
#   最大圆 - 圆心: (np.int64(191), np.int64(101)), 半径: 1.00
#   第二个圆 - 圆心: (np.int64(191), np.int64(101)), 半径: 1.00
#   第三个圆 - 圆心: (np.int64(191), np.int64(101)), 半径: 1.00
# Slice 25 - Region 1:
#   最大圆 - 圆心: (np.int64(105), np.int64(150)), 半径: 5.00
#   第二个圆 - 圆心: (np.int64(105), np.int64(150)), 半径: 5.00
#   第三个圆 - 圆心: (np.int64(105), np.int64(150)), 半径: 5.00
# Slice 25 - Region 2:
#   最大圆 - 圆心: (np.int64(192), np.int64(100)), 半径: 2.24
#   第二个圆 - 圆心: (np.int64(192), np.int64(100)), 半径: 2.24
#   第三个圆 - 圆心: (np.int64(192), np.int64(100)), 半径: 2.24
# Slice 26 - Region 1:
#   最大圆 - 圆心: (np.int64(106), np.int64(150)), 半径: 5.00
#   第二个圆 - 圆心: (np.int64(106), np.int64(150)), 半径: 5.00
#   第三个圆 - 圆心: (np.int64(106), np.int64(150)), 半径: 5.00
# Slice 26 - Region 2:
#   最大圆 - 圆心: (np.int64(194), np.int64(99)), 半径: 3.61
#   第二个圆 - 圆心: (np.int64(194), np.int64(99)), 半径: 3.61
#   第三个圆 - 圆心: (np.int64(194), np.int64(99)), 半径: 3.61
# Slice 26 - Region 3:
#   最大圆 - 圆心: (np.int64(224), np.int64(185)), 半径: 1.00
#   第二个圆 - 圆心: (np.int64(224), np.int64(185)), 半径: 1.00
#   第三个圆 - 圆心: (np.int64(224), np.int64(185)), 半径: 1.00
# Slice 27 - Region 1:
#   最大圆 - 圆心: (np.int64(107), np.int64(150)), 半径: 4.47
#   第二个圆 - 圆心: (np.int64(107), np.int64(150)), 半径: 4.47
#   第三个圆 - 圆心: (np.int64(107), np.int64(150)), 半径: 4.47
# Slice 27 - Region 2:
#   最大圆 - 圆心: (np.int64(194), np.int64(97)), 半径: 4.24
#   第二个圆 - 圆心: (np.int64(194), np.int64(97)), 半径: 4.24
#   第三个圆 - 圆心: (np.int64(194), np.int64(97)), 半径: 4.24
# Slice 27 - Region 3:
#   最大圆 - 圆心: (np.int64(224), np.int64(182)), 半径: 3.00
#   第二个圆 - 圆心: (np.int64(224), np.int64(182)), 半径: 3.00
#   第三个圆 - 圆心: (np.int64(224), np.int64(182)), 半径: 3.00
# Slice 28 - Region 1:
#   最大圆 - 圆心: (np.int64(108), np.int64(150)), 半径: 4.47
#   第二个圆 - 圆心: (np.int64(108), np.int64(150)), 半径: 4.47
#   第三个圆 - 圆心: (np.int64(108), np.int64(150)), 半径: 4.47
# Slice 28 - Region 2:
#   最大圆 - 圆心: (np.int64(195), np.int64(97)), 半径: 4.24
#   第二个圆 - 圆心: (np.int64(195), np.int64(97)), 半径: 4.24
#   第三个圆 - 圆心: (np.int64(195), np.int64(97)), 半径: 4.24
# Slice 28 - Region 3:
#   最大圆 - 圆心: (np.int64(223), np.int64(180)), 半径: 5.00
#   第二个圆 - 圆心: (np.int64(223), np.int64(180)), 半径: 5.00
#   第三个圆 - 圆心: (np.int64(223), np.int64(180)), 半径: 5.00
# Slice 29 - Region 1:
#   最大圆 - 圆心: (np.int64(108), np.int64(150)), 半径: 4.47
#   第二个圆 - 圆心: (np.int64(108), np.int64(150)), 半径: 4.47
#   第三个圆 - 圆心: (np.int64(108), np.int64(150)), 半径: 4.47
# Slice 29 - Region 2:
#   最大圆 - 圆心: (np.int64(195), np.int64(97)), 半径: 4.00
#   第二个圆 - 圆心: (np.int64(195), np.int64(97)), 半径: 4.00
#   第三个圆 - 圆心: (np.int64(195), np.int64(97)), 半径: 4.00
# Slice 29 - Region 3:
#   最大圆 - 圆心: (np.int64(223), np.int64(180)), 半径: 5.00
#   第二个圆 - 圆心: (np.int64(223), np.int64(180)), 半径: 5.00
#   第三个圆 - 圆心: (np.int64(223), np.int64(180)), 半径: 5.00
# Slice 30 - Region 1:
#   最大圆 - 圆心: (np.int64(109), np.int64(150)), 半径: 4.47
#   第二个圆 - 圆心: (np.int64(109), np.int64(150)), 半径: 4.47
#   第三个圆 - 圆心: (np.int64(109), np.int64(150)), 半径: 4.47
# Slice 30 - Region 2:
#   最大圆 - 圆心: (np.int64(196), np.int64(97)), 半径: 4.00
#   第二个圆 - 圆心: (np.int64(196), np.int64(97)), 半径: 4.00
#   第三个圆 - 圆心: (np.int64(196), np.int64(97)), 半径: 4.00
# Slice 30 - Region 3:
#   最大圆 - 圆心: (np.int64(224), np.int64(179)), 半径: 5.00
#   第二个圆 - 圆心: (np.int64(224), np.int64(179)), 半径: 5.00
#   第三个圆 - 圆心: (np.int64(224), np.int64(179)), 半径: 5.00
# Slice 31 - Region 1:
#   最大圆 - 圆心: (np.int64(109), np.int64(150)), 半径: 4.12
#   第二个圆 - 圆心: (np.int64(109), np.int64(150)), 半径: 4.12
#   第三个圆 - 圆心: (np.int64(109), np.int64(150)), 半径: 4.12
# Slice 31 - Region 2:
#   最大圆 - 圆心: (np.int64(196), np.int64(97)), 半径: 3.61
#   第二个圆 - 圆心: (np.int64(196), np.int64(97)), 半径: 3.61
#   第三个圆 - 圆心: (np.int64(196), np.int64(97)), 半径: 3.61
# Slice 31 - Region 3:
#   最大圆 - 圆心: (np.int64(224), np.int64(180)), 半径: 5.00
#   第二个圆 - 圆心: (np.int64(224), np.int64(180)), 半径: 5.00
#   第三个圆 - 圆心: (np.int64(224), np.int64(180)), 半径: 5.00
# Slice 32 - Region 1:
#   最大圆 - 圆心: (np.int64(110), np.int64(150)), 半径: 4.47
#   第二个圆 - 圆心: (np.int64(110), np.int64(150)), 半径: 4.47
#   第三个圆 - 圆心: (np.int64(110), np.int64(150)), 半径: 4.47
# Slice 32 - Region 2:
#   最大圆 - 圆心: (np.int64(197), np.int64(96)), 半径: 3.61
#   第二个圆 - 圆心: (np.int64(197), np.int64(96)), 半径: 3.61
#   第三个圆 - 圆心: (np.int64(197), np.int64(96)), 半径: 3.61
# Slice 32 - Region 3:
#   最大圆 - 圆心: (np.int64(224), np.int64(180)), 半径: 4.47
#   第二个圆 - 圆心: (np.int64(224), np.int64(180)), 半径: 4.47
#   第三个圆 - 圆心: (np.int64(224), np.int64(180)), 半径: 4.47
# Slice 33 - Region 1:
#   最大圆 - 圆心: (np.int64(111), np.int64(150)), 半径: 4.47
#   第二个圆 - 圆心: (np.int64(111), np.int64(150)), 半径: 4.47
#   第三个圆 - 圆心: (np.int64(111), np.int64(150)), 半径: 4.47
# Slice 33 - Region 2:
#   最大圆 - 圆心: (np.int64(197), np.int64(96)), 半径: 3.61
#   第二个圆 - 圆心: (np.int64(197), np.int64(96)), 半径: 3.61
#   第三个圆 - 圆心: (np.int64(197), np.int64(96)), 半径: 3.61
# Slice 33 - Region 3:
#   最大圆 - 圆心: (np.int64(225), np.int64(179)), 半径: 4.47
#   第二个圆 - 圆心: (np.int64(225), np.int64(179)), 半径: 4.47
#   第三个圆 - 圆心: (np.int64(225), np.int64(179)), 半径: 4.47
# Slice 34 - Region 1:
#   最大圆 - 圆心: (np.int64(111), np.int64(150)), 半径: 4.47
#   第二个圆 - 圆心: (np.int64(111), np.int64(150)), 半径: 4.47
#   第三个圆 - 圆心: (np.int64(111), np.int64(150)), 半径: 4.47
# Slice 34 - Region 2:
#   最大圆 - 圆心: (np.int64(197), np.int64(96)), 半径: 3.61
#   第二个圆 - 圆心: (np.int64(197), np.int64(96)), 半径: 3.61
#   第三个圆 - 圆心: (np.int64(197), np.int64(96)), 半径: 3.61
# Slice 34 - Region 3:
#   最大圆 - 圆心: (np.int64(225), np.int64(179)), 半径: 4.47
#   第二个圆 - 圆心: (np.int64(225), np.int64(179)), 半径: 4.47
#   第三个圆 - 圆心: (np.int64(225), np.int64(179)), 半径: 4.47
# Slice 35 - Region 1:
#   最大圆 - 圆心: (np.int64(112), np.int64(150)), 半径: 4.24
#   第二个圆 - 圆心: (np.int64(112), np.int64(150)), 半径: 4.24
#   第三个圆 - 圆心: (np.int64(112), np.int64(150)), 半径: 4.24
# Slice 35 - Region 2:
#   最大圆 - 圆心: (np.int64(198), np.int64(96)), 半径: 3.16
#   第二个圆 - 圆心: (np.int64(198), np.int64(96)), 半径: 3.16
#   第三个圆 - 圆心: (np.int64(198), np.int64(96)), 半径: 3.16
# Slice 35 - Region 3:
#   最大圆 - 圆心: (np.int64(225), np.int64(179)), 半径: 4.24
#   第二个圆 - 圆心: (np.int64(225), np.int64(179)), 半径: 4.24
#   第三个圆 - 圆心: (np.int64(225), np.int64(179)), 半径: 4.24
# Slice 36 - Region 1:
#   最大圆 - 圆心: (np.int64(112), np.int64(150)), 半径: 4.24
#   第二个圆 - 圆心: (np.int64(112), np.int64(150)), 半径: 4.24
#   第三个圆 - 圆心: (np.int64(112), np.int64(150)), 半径: 4.24
# Slice 36 - Region 2:
#   最大圆 - 圆心: (np.int64(198), np.int64(96)), 半径: 3.00
#   第二个圆 - 圆心: (np.int64(198), np.int64(96)), 半径: 3.00
#   第三个圆 - 圆心: (np.int64(198), np.int64(96)), 半径: 3.00
# Slice 36 - Region 3:
#   最大圆 - 圆心: (np.int64(224), np.int64(179)), 半径: 4.12
#   第二个圆 - 圆心: (np.int64(224), np.int64(179)), 半径: 4.12
#   第三个圆 - 圆心: (np.int64(224), np.int64(179)), 半径: 4.12
# Slice 37 - Region 1:
#   最大圆 - 圆心: (np.int64(112), np.int64(150)), 半径: 4.12
#   第二个圆 - 圆心: (np.int64(112), np.int64(150)), 半径: 4.12
#   第三个圆 - 圆心: (np.int64(112), np.int64(150)), 半径: 4.12
# Slice 37 - Region 2:
#   最大圆 - 圆心: (np.int64(198), np.int64(96)), 半径: 3.00
#   第二个圆 - 圆心: (np.int64(198), np.int64(96)), 半径: 3.00
#   第三个圆 - 圆心: (np.int64(198), np.int64(96)), 半径: 3.00
# Slice 37 - Region 3:
#   最大圆 - 圆心: (np.int64(224), np.int64(179)), 半径: 4.00
#   第二个圆 - 圆心: (np.int64(224), np.int64(179)), 半径: 4.00
#   第三个圆 - 圆心: (np.int64(224), np.int64(179)), 半径: 4.00
# Slice 38 - Region 1:
#   最大圆 - 圆心: (np.int64(105), np.int64(112)), 半径: 1.00
#   第二个圆 - 圆心: (np.int64(105), np.int64(112)), 半径: 1.00
#   第三个圆 - 圆心: (np.int64(105), np.int64(112)), 半径: 1.00
# Slice 38 - Region 2:
#   最大圆 - 圆心: (np.int64(113), np.int64(149)), 半径: 4.12
#   第二个圆 - 圆心: (np.int64(113), np.int64(149)), 半径: 4.12
#   第三个圆 - 圆心: (np.int64(113), np.int64(149)), 半径: 4.12
# Slice 38 - Region 3:
#   最大圆 - 圆心: (np.int64(198), np.int64(95)), 半径: 2.83
#   第二个圆 - 圆心: (np.int64(198), np.int64(95)), 半径: 2.83
#   第三个圆 - 圆心: (np.int64(198), np.int64(95)), 半径: 2.83
# Slice 38 - Region 4:
#   最大圆 - 圆心: (np.int64(225), np.int64(178)), 半径: 4.00
#   第二个圆 - 圆心: (np.int64(225), np.int64(178)), 半径: 4.00
#   第三个圆 - 圆心: (np.int64(225), np.int64(178)), 半径: 4.00
# Slice 39 - Region 1:
#   最大圆 - 圆心: (np.int64(106), np.int64(110)), 半径: 1.41
#   第二个圆 - 圆心: (np.int64(106), np.int64(110)), 半径: 1.41
#   第三个圆 - 圆心: (np.int64(106), np.int64(110)), 半径: 1.41
# Slice 39 - Region 2:
#   最大圆 - 圆心: (np.int64(112), np.int64(151)), 半径: 3.61
#   第二个圆 - 圆心: (np.int64(112), np.int64(151)), 半径: 3.61
#   第三个圆 - 圆心: (np.int64(112), np.int64(151)), 半径: 3.61
# Slice 39 - Region 3:
#   最大圆 - 圆心: (np.int64(198), np.int64(95)), 半径: 2.83
#   第二个圆 - 圆心: (np.int64(198), np.int64(95)), 半径: 2.83
#   第三个圆 - 圆心: (np.int64(198), np.int64(95)), 半径: 2.83
# Slice 39 - Region 4:
#   最大圆 - 圆心: (np.int64(225), np.int64(178)), 半径: 3.61
#   第二个圆 - 圆心: (np.int64(225), np.int64(178)), 半径: 3.61
#   第三个圆 - 圆心: (np.int64(225), np.int64(178)), 半径: 3.61
# Slice 40 - Region 1:
#   最大圆 - 圆心: (np.int64(106), np.int64(109)), 半径: 2.00
#   第二个圆 - 圆心: (np.int64(106), np.int64(109)), 半径: 2.00
#   第三个圆 - 圆心: (np.int64(106), np.int64(109)), 半径: 2.00
# Slice 40 - Region 2:
#   最大圆 - 圆心: (np.int64(113), np.int64(149)), 半径: 3.61
#   第二个圆 - 圆心: (np.int64(113), np.int64(149)), 半径: 3.61
#   第三个圆 - 圆心: (np.int64(113), np.int64(149)), 半径: 3.61
# Slice 40 - Region 3:
#   最大圆 - 圆心: (np.int64(198), np.int64(95)), 半径: 2.83
#   第二个圆 - 圆心: (np.int64(198), np.int64(95)), 半径: 2.83
#   第三个圆 - 圆心: (np.int64(198), np.int64(95)), 半径: 2.83
# Slice 40 - Region 4:
#   最大圆 - 圆心: (np.int64(225), np.int64(178)), 半径: 3.61
#   第二个圆 - 圆心: (np.int64(225), np.int64(178)), 半径: 3.61
#   第三个圆 - 圆心: (np.int64(225), np.int64(178)), 半径: 3.61
# Slice 41 - Region 1:
#   最大圆 - 圆心: (np.int64(106), np.int64(108)), 半径: 2.24
#   第二个圆 - 圆心: (np.int64(106), np.int64(108)), 半径: 2.24
#   第三个圆 - 圆心: (np.int64(106), np.int64(108)), 半径: 2.24
# Slice 41 - Region 2:
#   最大圆 - 圆心: (np.int64(113), np.int64(149)), 半径: 3.61
#   第二个圆 - 圆心: (np.int64(113), np.int64(149)), 半径: 3.61
#   第三个圆 - 圆心: (np.int64(113), np.int64(149)), 半径: 3.61
# Slice 41 - Region 3:
#   最大圆 - 圆心: (np.int64(199), np.int64(95)), 半径: 2.83
#   第二个圆 - 圆心: (np.int64(199), np.int64(95)), 半径: 2.83
#   第三个圆 - 圆心: (np.int64(199), np.int64(95)), 半径: 2.83
# Slice 41 - Region 4:
#   最大圆 - 圆心: (np.int64(225), np.int64(179)), 半径: 3.16
#   第二个圆 - 圆心: (np.int64(225), np.int64(179)), 半径: 3.16
#   第三个圆 - 圆心: (np.int64(225), np.int64(179)), 半径: 3.16
# Slice 42 - Region 1:
#   最大圆 - 圆心: (np.int64(105), np.int64(109)), 半径: 2.83
#   第二个圆 - 圆心: (np.int64(105), np.int64(109)), 半径: 2.83
#   第三个圆 - 圆心: (np.int64(105), np.int64(109)), 半径: 2.83
# Slice 42 - Region 2:
#   最大圆 - 圆心: (np.int64(113), np.int64(149)), 半径: 3.61
#   第二个圆 - 圆心: (np.int64(113), np.int64(149)), 半径: 3.61
#   第三个圆 - 圆心: (np.int64(113), np.int64(149)), 半径: 3.61
# Slice 42 - Region 3:
#   最大圆 - 圆心: (np.int64(199), np.int64(95)), 半径: 2.83
#   第二个圆 - 圆心: (np.int64(199), np.int64(95)), 半径: 2.83
#   第三个圆 - 圆心: (np.int64(199), np.int64(95)), 半径: 2.83
# Slice 42 - Region 4:
#   最大圆 - 圆心: (np.int64(225), np.int64(179)), 半径: 3.61
#   第二个圆 - 圆心: (np.int64(225), np.int64(179)), 半径: 3.61
#   第三个圆 - 圆心: (np.int64(225), np.int64(179)), 半径: 3.61
# Slice 43 - Region 1:
#   最大圆 - 圆心: (np.int64(105), np.int64(108)), 半径: 3.61
#   第二个圆 - 圆心: (np.int64(105), np.int64(108)), 半径: 3.61
#   第三个圆 - 圆心: (np.int64(105), np.int64(108)), 半径: 3.61
# Slice 43 - Region 2:
#   最大圆 - 圆心: (np.int64(113), np.int64(149)), 半径: 3.61
#   第二个圆 - 圆心: (np.int64(113), np.int64(149)), 半径: 3.61
#   第三个圆 - 圆心: (np.int64(113), np.int64(149)), 半径: 3.61
# Slice 43 - Region 3:
#   最大圆 - 圆心: (np.int64(199), np.int64(95)), 半径: 2.83
#   第二个圆 - 圆心: (np.int64(199), np.int64(95)), 半径: 2.83
#   第三个圆 - 圆心: (np.int64(199), np.int64(95)), 半径: 2.83
# Slice 43 - Region 4:
#   最大圆 - 圆心: (np.int64(225), np.int64(179)), 半径: 3.61
#   第二个圆 - 圆心: (np.int64(225), np.int64(179)), 半径: 3.61
#   第三个圆 - 圆心: (np.int64(225), np.int64(179)), 半径: 3.61
# Slice 44 - Region 1:
#   最大圆 - 圆心: (np.int64(106), np.int64(106)), 半径: 4.12
#   第二个圆 - 圆心: (np.int64(106), np.int64(106)), 半径: 4.12
#   第三个圆 - 圆心: (np.int64(106), np.int64(106)), 半径: 4.12
# Slice 44 - Region 2:
#   最大圆 - 圆心: (np.int64(113), np.int64(149)), 半径: 3.16
#   第二个圆 - 圆心: (np.int64(113), np.int64(149)), 半径: 3.16
#   第三个圆 - 圆心: (np.int64(113), np.int64(149)), 半径: 3.16
# Slice 44 - Region 3:
#   最大圆 - 圆心: (np.int64(199), np.int64(95)), 半径: 2.00
#   第二个圆 - 圆心: (np.int64(199), np.int64(95)), 半径: 2.00
#   第三个圆 - 圆心: (np.int64(199), np.int64(95)), 半径: 2.00
# Slice 44 - Region 4:
#   最大圆 - 圆心: (np.int64(225), np.int64(179)), 半径: 3.61
#   第二个圆 - 圆心: (np.int64(225), np.int64(179)), 半径: 3.61
#   第三个圆 - 圆心: (np.int64(225), np.int64(179)), 半径: 3.61
# Slice 45 - Region 1:
#   最大圆 - 圆心: (np.int64(106), np.int64(106)), 半径: 5.00
#   第二个圆 - 圆心: (np.int64(106), np.int64(106)), 半径: 5.00
#   第三个圆 - 圆心: (np.int64(106), np.int64(106)), 半径: 5.00
# Slice 45 - Region 2:
#   最大圆 - 圆心: (np.int64(112), np.int64(151)), 半径: 3.00
#   第二个圆 - 圆心: (np.int64(112), np.int64(151)), 半径: 3.00
#   第三个圆 - 圆心: (np.int64(112), np.int64(151)), 半径: 3.00
# Slice 45 - Region 3:
#   最大圆 - 圆心: (np.int64(200), np.int64(95)), 半径: 2.00
#   第二个圆 - 圆心: (np.int64(200), np.int64(95)), 半径: 2.00
#   第三个圆 - 圆心: (np.int64(200), np.int64(95)), 半径: 2.00
# Slice 45 - Region 4:
#   最大圆 - 圆心: (np.int64(226), np.int64(179)), 半径: 3.61
#   第二个圆 - 圆心: (np.int64(226), np.int64(179)), 半径: 3.61
#   第三个圆 - 圆心: (np.int64(226), np.int64(179)), 半径: 3.61
# Slice 46 - Region 1:
#   最大圆 - 圆心: (np.int64(105), np.int64(106)), 半径: 5.00
#   第二个圆 - 圆心: (np.int64(105), np.int64(106)), 半径: 5.00
#   第三个圆 - 圆心: (np.int64(105), np.int64(106)), 半径: 5.00
# Slice 46 - Region 2:
#   最大圆 - 圆心: (np.int64(112), np.int64(151)), 半径: 3.00
#   第二个圆 - 圆心: (np.int64(112), np.int64(151)), 半径: 3.00
#   第三个圆 - 圆心: (np.int64(112), np.int64(151)), 半径: 3.00
# Slice 46 - Region 3:
#   最大圆 - 圆心: (np.int64(201), np.int64(95)), 半径: 2.00
#   第二个圆 - 圆心: (np.int64(201), np.int64(95)), 半径: 2.00
#   第三个圆 - 圆心: (np.int64(201), np.int64(95)), 半径: 2.00
# Slice 46 - Region 4:
#   最大圆 - 圆心: (np.int64(226), np.int64(179)), 半径: 3.61
#   第二个圆 - 圆心: (np.int64(226), np.int64(179)), 半径: 3.61
#   第三个圆 - 圆心: (np.int64(226), np.int64(179)), 半径: 3.61
# Slice 47 - Region 1:
#   最大圆 - 圆心: (np.int64(105), np.int64(106)), 半径: 5.39
#   第二个圆 - 圆心: (np.int64(105), np.int64(106)), 半径: 5.39
#   第三个圆 - 圆心: (np.int64(105), np.int64(106)), 半径: 5.39
# Slice 47 - Region 2:
#   最大圆 - 圆心: (np.int64(112), np.int64(151)), 半径: 3.16
#   第二个圆 - 圆心: (np.int64(112), np.int64(151)), 半径: 3.16
#   第三个圆 - 圆心: (np.int64(112), np.int64(151)), 半径: 3.16
# Slice 47 - Region 3:
#   最大圆 - 圆心: (np.int64(201), np.int64(95)), 半径: 1.41
#   第二个圆 - 圆心: (np.int64(201), np.int64(95)), 半径: 1.41
#   第三个圆 - 圆心: (np.int64(201), np.int64(95)), 半径: 1.41
# Slice 47 - Region 4:
#   最大圆 - 圆心: (np.int64(227), np.int64(179)), 半径: 3.61
#   第二个圆 - 圆心: (np.int64(227), np.int64(179)), 半径: 3.61
#   第三个圆 - 圆心: (np.int64(227), np.int64(179)), 半径: 3.61
# Slice 48 - Region 1:
#   最大圆 - 圆心: (np.int64(105), np.int64(105)), 半径: 5.83
#   第二个圆 - 圆心: (np.int64(105), np.int64(105)), 半径: 5.83
#   第三个圆 - 圆心: (np.int64(105), np.int64(105)), 半径: 5.83
# Slice 48 - Region 2:
#   最大圆 - 圆心: (np.int64(112), np.int64(152)), 半径: 3.61
#   第二个圆 - 圆心: (np.int64(112), np.int64(152)), 半径: 3.61
#   第三个圆 - 圆心: (np.int64(112), np.int64(152)), 半径: 3.61
# Slice 48 - Region 3:
#   最大圆 - 圆心: (np.int64(201), np.int64(94)), 半径: 1.00
#   第二个圆 - 圆心: (np.int64(201), np.int64(94)), 半径: 1.00
#   第三个圆 - 圆心: (np.int64(201), np.int64(94)), 半径: 1.00
# Slice 48 - Region 4:
#   最大圆 - 圆心: (np.int64(228), np.int64(179)), 半径: 3.61
#   第二个圆 - 圆心: (np.int64(228), np.int64(179)), 半径: 3.61
#   第三个圆 - 圆心: (np.int64(228), np.int64(179)), 半径: 3.61
# Slice 49 - Region 1:
#   最大圆 - 圆心: (np.int64(104), np.int64(106)), 半径: 5.83
#   第二个圆 - 圆心: (np.int64(104), np.int64(106)), 半径: 5.83
#   第三个圆 - 圆心: (np.int64(104), np.int64(106)), 半径: 5.83
# Slice 49 - Region 2:
#   最大圆 - 圆心: (np.int64(112), np.int64(152)), 半径: 3.61
#   第二个圆 - 圆心: (np.int64(112), np.int64(152)), 半径: 3.61
#   第三个圆 - 圆心: (np.int64(112), np.int64(152)), 半径: 3.61
# Slice 49 - Region 3:
#   最大圆 - 圆心: (np.int64(201), np.int64(94)), 半径: 1.00
#   第二个圆 - 圆心: (np.int64(201), np.int64(94)), 半径: 1.00
#   第三个圆 - 圆心: (np.int64(201), np.int64(94)), 半径: 1.00
# Slice 49 - Region 4:
#   最大圆 - 圆心: (np.int64(228), np.int64(179)), 半径: 3.61
#   第二个圆 - 圆心: (np.int64(228), np.int64(179)), 半径: 3.61
#   第三个圆 - 圆心: (np.int64(228), np.int64(179)), 半径: 3.61
# Slice 50 - Region 1:
#   最大圆 - 圆心: (np.int64(104), np.int64(106)), 半径: 5.83
#   第二个圆 - 圆心: (np.int64(104), np.int64(106)), 半径: 5.83
#   第三个圆 - 圆心: (np.int64(104), np.int64(106)), 半径: 5.83
# Slice 50 - Region 2:
#   最大圆 - 圆心: (np.int64(112), np.int64(152)), 半径: 3.61
#   第二个圆 - 圆心: (np.int64(112), np.int64(152)), 半径: 3.61
#   第三个圆 - 圆心: (np.int64(112), np.int64(152)), 半径: 3.61
# Slice 50 - Region 3:
#   最大圆 - 圆心: (np.int64(201), np.int64(94)), 半径: 1.00
#   第二个圆 - 圆心: (np.int64(201), np.int64(94)), 半径: 1.00
#   第三个圆 - 圆心: (np.int64(201), np.int64(94)), 半径: 1.00
# Slice 50 - Region 4:
#   最大圆 - 圆心: (np.int64(229), np.int64(178)), 半径: 3.61
#   第二个圆 - 圆心: (np.int64(229), np.int64(178)), 半径: 3.61
#   第三个圆 - 圆心: (np.int64(229), np.int64(178)), 半径: 3.61
# Slice 51 - Region 1:
#   最大圆 - 圆心: (np.int64(103), np.int64(106)), 半径: 5.00
#   第二个圆 - 圆心: (np.int64(103), np.int64(106)), 半径: 5.00
#   第三个圆 - 圆心: (np.int64(103), np.int64(106)), 半径: 5.00
# Slice 51 - Region 2:
#   最大圆 - 圆心: (np.int64(112), np.int64(152)), 半径: 3.61
#   第二个圆 - 圆心: (np.int64(112), np.int64(152)), 半径: 3.61
#   第三个圆 - 圆心: (np.int64(112), np.int64(152)), 半径: 3.61
# Slice 51 - Region 3:
#   最大圆 - 圆心: (np.int64(201), np.int64(94)), 半径: 1.00
#   第二个圆 - 圆心: (np.int64(201), np.int64(94)), 半径: 1.00
#   第三个圆 - 圆心: (np.int64(201), np.int64(94)), 半径: 1.00
# Slice 51 - Region 4:
#   最大圆 - 圆心: (np.int64(229), np.int64(178)), 半径: 3.61
#   第二个圆 - 圆心: (np.int64(229), np.int64(178)), 半径: 3.61
#   第三个圆 - 圆心: (np.int64(229), np.int64(178)), 半径: 3.61
# Slice 52 - Region 1:
#   最大圆 - 圆心: (np.int64(105), np.int64(106)), 半径: 5.00
#   第二个圆 - 圆心: (np.int64(105), np.int64(106)), 半径: 5.00
#   第三个圆 - 圆心: (np.int64(105), np.int64(106)), 半径: 5.00
# Slice 52 - Region 2:
#   最大圆 - 圆心: (np.int64(112), np.int64(152)), 半径: 3.61
#   第二个圆 - 圆心: (np.int64(112), np.int64(152)), 半径: 3.61
#   第三个圆 - 圆心: (np.int64(112), np.int64(152)), 半径: 3.61
# Slice 52 - Region 3:
#   最大圆 - 圆心: (np.int64(201), np.int64(94)), 半径: 1.00
#   第二个圆 - 圆心: (np.int64(201), np.int64(94)), 半径: 1.00
#   第三个圆 - 圆心: (np.int64(201), np.int64(94)), 半径: 1.00
# Slice 52 - Region 4:
#   最大圆 - 圆心: (np.int64(229), np.int64(178)), 半径: 3.16
#   第二个圆 - 圆心: (np.int64(229), np.int64(178)), 半径: 3.16
#   第三个圆 - 圆心: (np.int64(229), np.int64(178)), 半径: 3.16
# Slice 53 - Region 1:
#   最大圆 - 圆心: (np.int64(107), np.int64(106)), 半径: 5.00
#   第二个圆 - 圆心: (np.int64(107), np.int64(106)), 半径: 5.00
#   第三个圆 - 圆心: (np.int64(107), np.int64(106)), 半径: 5.00
# Slice 53 - Region 2:
#   最大圆 - 圆心: (np.int64(112), np.int64(152)), 半径: 3.16
#   第二个圆 - 圆心: (np.int64(112), np.int64(152)), 半径: 3.16
#   第三个圆 - 圆心: (np.int64(112), np.int64(152)), 半径: 3.16
# Slice 53 - Region 3:
#   最大圆 - 圆心: (np.int64(201), np.int64(94)), 半径: 1.00
#   第二个圆 - 圆心: (np.int64(201), np.int64(94)), 半径: 1.00
#   第三个圆 - 圆心: (np.int64(201), np.int64(94)), 半径: 1.00
# Slice 53 - Region 4:
#   最大圆 - 圆心: (np.int64(229), np.int64(178)), 半径: 3.00
#   第二个圆 - 圆心: (np.int64(229), np.int64(178)), 半径: 3.00
#   第三个圆 - 圆心: (np.int64(229), np.int64(178)), 半径: 3.00
# Slice 54 - Region 1:
#   最大圆 - 圆心: (np.int64(109), np.int64(106)), 半径: 5.39
#   第二个圆 - 圆心: (np.int64(109), np.int64(106)), 半径: 5.39
#   第三个圆 - 圆心: (np.int64(109), np.int64(106)), 半径: 5.39
# Slice 54 - Region 2:
#   最大圆 - 圆心: (np.int64(112), np.int64(153)), 半径: 3.16
#   第二个圆 - 圆心: (np.int64(112), np.int64(153)), 半径: 3.16
#   第三个圆 - 圆心: (np.int64(112), np.int64(153)), 半径: 3.16
# Slice 54 - Region 3:
#   最大圆 - 圆心: (np.int64(202), np.int64(94)), 半径: 1.41
#   第二个圆 - 圆心: (np.int64(202), np.int64(94)), 半径: 1.41
#   第三个圆 - 圆心: (np.int64(202), np.int64(94)), 半径: 1.41
# Slice 54 - Region 4:
#   最大圆 - 圆心: (np.int64(230), np.int64(178)), 半径: 3.16
#   第二个圆 - 圆心: (np.int64(230), np.int64(178)), 半径: 3.16
#   第三个圆 - 圆心: (np.int64(230), np.int64(178)), 半径: 3.16
# Slice 55 - Region 1:
#   最大圆 - 圆心: (np.int64(110), np.int64(106)), 半径: 5.66
#   第二个圆 - 圆心: (np.int64(110), np.int64(106)), 半径: 5.66
#   第三个圆 - 圆心: (np.int64(110), np.int64(106)), 半径: 5.66
# Slice 55 - Region 2:
#   最大圆 - 圆心: (np.int64(112), np.int64(153)), 半径: 3.00
#   第二个圆 - 圆心: (np.int64(112), np.int64(153)), 半径: 3.00
#   第三个圆 - 圆心: (np.int64(112), np.int64(153)), 半径: 3.00
# Slice 55 - Region 3:
#   最大圆 - 圆心: (np.int64(202), np.int64(94)), 半径: 1.41
#   第二个圆 - 圆心: (np.int64(202), np.int64(94)), 半径: 1.41
#   第三个圆 - 圆心: (np.int64(202), np.int64(94)), 半径: 1.41
# Slice 55 - Region 4:
#   最大圆 - 圆心: (np.int64(230), np.int64(178)), 半径: 3.16
#   第二个圆 - 圆心: (np.int64(230), np.int64(178)), 半径: 3.16
#   第三个圆 - 圆心: (np.int64(230), np.int64(178)), 半径: 3.16
# Slice 56 - Region 1:
#   最大圆 - 圆心: (np.int64(110), np.int64(106)), 半径: 5.39
#   第二个圆 - 圆心: (np.int64(110), np.int64(106)), 半径: 5.39
#   第三个圆 - 圆心: (np.int64(110), np.int64(106)), 半径: 5.39
# Slice 56 - Region 2:
#   最大圆 - 圆心: (np.int64(112), np.int64(153)), 半径: 3.16
#   第二个圆 - 圆心: (np.int64(112), np.int64(153)), 半径: 3.16
#   第三个圆 - 圆心: (np.int64(112), np.int64(153)), 半径: 3.16
# Slice 56 - Region 3:
#   最大圆 - 圆心: (np.int64(202), np.int64(94)), 半径: 1.41
#   第二个圆 - 圆心: (np.int64(202), np.int64(94)), 半径: 1.41
#   第三个圆 - 圆心: (np.int64(202), np.int64(94)), 半径: 1.41
# Slice 56 - Region 4:
#   最大圆 - 圆心: (np.int64(230), np.int64(179)), 半径: 3.61
#   第二个圆 - 圆心: (np.int64(230), np.int64(179)), 半径: 3.61
#   第三个圆 - 圆心: (np.int64(230), np.int64(179)), 半径: 3.61
# Slice 57 - Region 1:
#   最大圆 - 圆心: (np.int64(111), np.int64(106)), 半径: 5.66
#   第二个圆 - 圆心: (np.int64(111), np.int64(106)), 半径: 5.66
#   第三个圆 - 圆心: (np.int64(111), np.int64(106)), 半径: 5.66
# Slice 57 - Region 2:
#   最大圆 - 圆心: (np.int64(112), np.int64(153)), 半径: 3.16
#   第二个圆 - 圆心: (np.int64(112), np.int64(153)), 半径: 3.16
#   第三个圆 - 圆心: (np.int64(112), np.int64(153)), 半径: 3.16
# Slice 57 - Region 3:
#   最大圆 - 圆心: (np.int64(201), np.int64(94)), 半径: 1.41
#   第二个圆 - 圆心: (np.int64(201), np.int64(94)), 半径: 1.41
#   第三个圆 - 圆心: (np.int64(201), np.int64(94)), 半径: 1.41
# Slice 57 - Region 4:
#   最大圆 - 圆心: (np.int64(231), np.int64(179)), 半径: 3.61
#   第二个圆 - 圆心: (np.int64(231), np.int64(179)), 半径: 3.61
#   第三个圆 - 圆心: (np.int64(231), np.int64(179)), 半径: 3.61
# Slice 58 - Region 1:
#   最大圆 - 圆心: (np.int64(111), np.int64(106)), 半径: 5.00
#   第二个圆 - 圆心: (np.int64(111), np.int64(106)), 半径: 5.00
#   第三个圆 - 圆心: (np.int64(111), np.int64(106)), 半径: 5.00
# Slice 58 - Region 2:
#   最大圆 - 圆心: (np.int64(112), np.int64(154)), 半径: 3.00
#   第二个圆 - 圆心: (np.int64(112), np.int64(154)), 半径: 3.00
#   第三个圆 - 圆心: (np.int64(112), np.int64(154)), 半径: 3.00
# Slice 58 - Region 3:
#   最大圆 - 圆心: (np.int64(201), np.int64(94)), 半径: 1.41
#   第二个圆 - 圆心: (np.int64(201), np.int64(94)), 半径: 1.41
#   第三个圆 - 圆心: (np.int64(201), np.int64(94)), 半径: 1.41
# Slice 58 - Region 4:
#   最大圆 - 圆心: (np.int64(231), np.int64(179)), 半径: 3.61
#   第二个圆 - 圆心: (np.int64(231), np.int64(179)), 半径: 3.61
#   第三个圆 - 圆心: (np.int64(231), np.int64(179)), 半径: 3.61
# Slice 59 - Region 1:
#   最大圆 - 圆心: (np.int64(112), np.int64(106)), 半径: 5.10
#   第二个圆 - 圆心: (np.int64(112), np.int64(106)), 半径: 5.10
#   第三个圆 - 圆心: (np.int64(112), np.int64(106)), 半径: 5.10
# Slice 59 - Region 2:
#   最大圆 - 圆心: (np.int64(112), np.int64(154)), 半径: 3.00
#   第二个圆 - 圆心: (np.int64(112), np.int64(154)), 半径: 3.00
#   第三个圆 - 圆心: (np.int64(112), np.int64(154)), 半径: 3.00
# Slice 59 - Region 3:
#   最大圆 - 圆心: (np.int64(202), np.int64(94)), 半径: 1.41
#   第二个圆 - 圆心: (np.int64(202), np.int64(94)), 半径: 1.41
#   第三个圆 - 圆心: (np.int64(202), np.int64(94)), 半径: 1.41
# Slice 59 - Region 4:
#   最大圆 - 圆心: (np.int64(231), np.int64(179)), 半径: 3.61
#   第二个圆 - 圆心: (np.int64(231), np.int64(179)), 半径: 3.61
#   第三个圆 - 圆心: (np.int64(231), np.int64(179)), 半径: 3.61
# Slice 60 - Region 1:
#   最大圆 - 圆心: (np.int64(113), np.int64(106)), 半径: 5.10
#   第二个圆 - 圆心: (np.int64(113), np.int64(106)), 半径: 5.10
#   第三个圆 - 圆心: (np.int64(113), np.int64(106)), 半径: 5.10
# Slice 60 - Region 2:
#   最大圆 - 圆心: (np.int64(111), np.int64(155)), 半径: 3.00
#   第二个圆 - 圆心: (np.int64(111), np.int64(155)), 半径: 3.00
#   第三个圆 - 圆心: (np.int64(111), np.int64(155)), 半径: 3.00
# Slice 60 - Region 3:
#   最大圆 - 圆心: (np.int64(202), np.int64(94)), 半径: 1.41
#   第二个圆 - 圆心: (np.int64(202), np.int64(94)), 半径: 1.41
#   第三个圆 - 圆心: (np.int64(202), np.int64(94)), 半径: 1.41
# Slice 60 - Region 4:
#   最大圆 - 圆心: (np.int64(231), np.int64(179)), 半径: 3.16
#   第二个圆 - 圆心: (np.int64(231), np.int64(179)), 半径: 3.16
#   第三个圆 - 圆心: (np.int64(231), np.int64(179)), 半径: 3.16
# Slice 61 - Region 1:
#   最大圆 - 圆心: (np.int64(113), np.int64(106)), 半径: 5.10
#   第二个圆 - 圆心: (np.int64(113), np.int64(106)), 半径: 5.10
#   第三个圆 - 圆心: (np.int64(113), np.int64(106)), 半径: 5.10
# Slice 61 - Region 2:
#   最大圆 - 圆心: (np.int64(111), np.int64(155)), 半径: 3.00
#   第二个圆 - 圆心: (np.int64(111), np.int64(155)), 半径: 3.00
#   第三个圆 - 圆心: (np.int64(111), np.int64(155)), 半径: 3.00
# Slice 61 - Region 3:
#   最大圆 - 圆心: (np.int64(201), np.int64(94)), 半径: 1.00
#   第二个圆 - 圆心: (np.int64(201), np.int64(94)), 半径: 1.00
#   第三个圆 - 圆心: (np.int64(201), np.int64(94)), 半径: 1.00
# Slice 61 - Region 4:
#   最大圆 - 圆心: (np.int64(232), np.int64(179)), 半径: 3.61
#   第二个圆 - 圆心: (np.int64(232), np.int64(179)), 半径: 3.61
#   第三个圆 - 圆心: (np.int64(232), np.int64(179)), 半径: 3.61
# Slice 62 - Region 1:
#   最大圆 - 圆心: (np.int64(114), np.int64(106)), 半径: 5.00
#   第二个圆 - 圆心: (np.int64(114), np.int64(106)), 半径: 5.00
#   第三个圆 - 圆心: (np.int64(114), np.int64(106)), 半径: 5.00
# Slice 62 - Region 2:
#   最大圆 - 圆心: (np.int64(111), np.int64(156)), 半径: 3.00
#   第二个圆 - 圆心: (np.int64(111), np.int64(156)), 半径: 3.00
#   第三个圆 - 圆心: (np.int64(111), np.int64(156)), 半径: 3.00
# Slice 62 - Region 3:
#   最大圆 - 圆心: (np.int64(201), np.int64(94)), 半径: 1.00
#   第二个圆 - 圆心: (np.int64(201), np.int64(94)), 半径: 1.00
#   第三个圆 - 圆心: (np.int64(201), np.int64(94)), 半径: 1.00
# Slice 62 - Region 4:
#   最大圆 - 圆心: (np.int64(232), np.int64(180)), 半径: 3.61
#   第二个圆 - 圆心: (np.int64(232), np.int64(180)), 半径: 3.61
#   第三个圆 - 圆心: (np.int64(232), np.int64(180)), 半径: 3.61
# Slice 63 - Region 1:
#   最大圆 - 圆心: (np.int64(111), np.int64(156)), 半径: 3.16
#   第二个圆 - 圆心: (np.int64(111), np.int64(156)), 半径: 3.16
#   第三个圆 - 圆心: (np.int64(111), np.int64(156)), 半径: 3.16
# Slice 63 - Region 2:
#   最大圆 - 圆心: (np.int64(114), np.int64(106)), 半径: 5.00
#   第二个圆 - 圆心: (np.int64(114), np.int64(106)), 半径: 5.00
#   第三个圆 - 圆心: (np.int64(114), np.int64(106)), 半径: 5.00
# Slice 63 - Region 3:
#   最大圆 - 圆心: (np.int64(201), np.int64(93)), 半径: 1.00
#   第二个圆 - 圆心: (np.int64(201), np.int64(93)), 半径: 1.00
#   第三个圆 - 圆心: (np.int64(201), np.int64(93)), 半径: 1.00
# Slice 63 - Region 4:
#   最大圆 - 圆心: (np.int64(232), np.int64(180)), 半径: 3.16
#   第二个圆 - 圆心: (np.int64(232), np.int64(180)), 半径: 3.16
#   第三个圆 - 圆心: (np.int64(232), np.int64(180)), 半径: 3.16
# Slice 64 - Region 1:
#   最大圆 - 圆心: (np.int64(111), np.int64(156)), 半径: 3.16
#   第二个圆 - 圆心: (np.int64(111), np.int64(156)), 半径: 3.16
#   第三个圆 - 圆心: (np.int64(111), np.int64(156)), 半径: 3.16
# Slice 64 - Region 2:
#   最大圆 - 圆心: (np.int64(114), np.int64(106)), 半径: 4.47
#   第二个圆 - 圆心: (np.int64(114), np.int64(106)), 半径: 4.47
#   第三个圆 - 圆心: (np.int64(114), np.int64(106)), 半径: 4.47
# Slice 64 - Region 3:
#   最大圆 - 圆心: (np.int64(201), np.int64(93)), 半径: 1.00
#   第二个圆 - 圆心: (np.int64(201), np.int64(93)), 半径: 1.00
#   第三个圆 - 圆心: (np.int64(201), np.int64(93)), 半径: 1.00
# Slice 64 - Region 4:
#   最大圆 - 圆心: (np.int64(233), np.int64(181)), 半径: 3.16
#   第二个圆 - 圆心: (np.int64(233), np.int64(181)), 半径: 3.16
#   第三个圆 - 圆心: (np.int64(233), np.int64(181)), 半径: 3.16
# Slice 65 - Region 1:
#   最大圆 - 圆心: (np.int64(111), np.int64(156)), 半径: 3.00
#   第二个圆 - 圆心: (np.int64(111), np.int64(156)), 半径: 3.00
#   第三个圆 - 圆心: (np.int64(111), np.int64(156)), 半径: 3.00
# Slice 65 - Region 2:
#   最大圆 - 圆心: (np.int64(115), np.int64(106)), 半径: 4.47
#   第二个圆 - 圆心: (np.int64(115), np.int64(106)), 半径: 4.47
#   第三个圆 - 圆心: (np.int64(115), np.int64(106)), 半径: 4.47
# Slice 65 - Region 3:
#   最大圆 - 圆心: (np.int64(201), np.int64(93)), 半径: 1.00
#   第二个圆 - 圆心: (np.int64(201), np.int64(93)), 半径: 1.00
#   第三个圆 - 圆心: (np.int64(201), np.int64(93)), 半径: 1.00
# Slice 65 - Region 4:
#   最大圆 - 圆心: (np.int64(233), np.int64(181)), 半径: 3.61
#   第二个圆 - 圆心: (np.int64(233), np.int64(181)), 半径: 3.61
#   第三个圆 - 圆心: (np.int64(233), np.int64(181)), 半径: 3.61
# Slice 66 - Region 1:
#   最大圆 - 圆心: (np.int64(111), np.int64(156)), 半径: 3.00
#   第二个圆 - 圆心: (np.int64(111), np.int64(156)), 半径: 3.00
#   第三个圆 - 圆心: (np.int64(111), np.int64(156)), 半径: 3.00
# Slice 66 - Region 2:
#   最大圆 - 圆心: (np.int64(116), np.int64(105)), 半径: 4.12
#   第二个圆 - 圆心: (np.int64(116), np.int64(105)), 半径: 4.12
#   第三个圆 - 圆心: (np.int64(116), np.int64(105)), 半径: 4.12
# Slice 66 - Region 3:
#   最大圆 - 圆心: (np.int64(202), np.int64(94)), 半径: 1.41
#   第二个圆 - 圆心: (np.int64(202), np.int64(94)), 半径: 1.41
#   第三个圆 - 圆心: (np.int64(202), np.int64(94)), 半径: 1.41
# Slice 66 - Region 4:
#   最大圆 - 圆心: (np.int64(233), np.int64(182)), 半径: 3.00
#   第二个圆 - 圆心: (np.int64(233), np.int64(182)), 半径: 3.00
#   第三个圆 - 圆心: (np.int64(233), np.int64(182)), 半径: 3.00
# Slice 67 - Region 1:
#   最大圆 - 圆心: (np.int64(111), np.int64(157)), 半径: 3.00
#   第二个圆 - 圆心: (np.int64(111), np.int64(157)), 半径: 3.00
#   第三个圆 - 圆心: (np.int64(111), np.int64(157)), 半径: 3.00
# Slice 67 - Region 2:
#   最大圆 - 圆心: (np.int64(116), np.int64(106)), 半径: 4.47
#   第二个圆 - 圆心: (np.int64(116), np.int64(106)), 半径: 4.47
#   第三个圆 - 圆心: (np.int64(116), np.int64(106)), 半径: 4.47
# Slice 67 - Region 3:
#   最大圆 - 圆心: (np.int64(201), np.int64(93)), 半径: 1.00
#   第二个圆 - 圆心: (np.int64(201), np.int64(93)), 半径: 1.00
#   第三个圆 - 圆心: (np.int64(201), np.int64(93)), 半径: 1.00
# Slice 67 - Region 4:
#   最大圆 - 圆心: (np.int64(234), np.int64(182)), 半径: 3.16
#   第二个圆 - 圆心: (np.int64(234), np.int64(182)), 半径: 3.16
#   第三个圆 - 圆心: (np.int64(234), np.int64(182)), 半径: 3.16
# Slice 68 - Region 1:
#   最大圆 - 圆心: (np.int64(110), np.int64(157)), 半径: 3.00
#   第二个圆 - 圆心: (np.int64(110), np.int64(157)), 半径: 3.00
#   第三个圆 - 圆心: (np.int64(110), np.int64(157)), 半径: 3.00
# Slice 68 - Region 2:
#   最大圆 - 圆心: (np.int64(116), np.int64(106)), 半径: 4.00
#   第二个圆 - 圆心: (np.int64(116), np.int64(106)), 半径: 4.00
#   第三个圆 - 圆心: (np.int64(116), np.int64(106)), 半径: 4.00
# Slice 68 - Region 3:
#   最大圆 - 圆心: (np.int64(201), np.int64(93)), 半径: 1.00
#   第二个圆 - 圆心: (np.int64(201), np.int64(93)), 半径: 1.00
#   第三个圆 - 圆心: (np.int64(201), np.int64(93)), 半径: 1.00
# Slice 68 - Region 4:
#   最大圆 - 圆心: (np.int64(234), np.int64(182)), 半径: 3.00
#   第二个圆 - 圆心: (np.int64(234), np.int64(182)), 半径: 3.00
#   第三个圆 - 圆心: (np.int64(234), np.int64(182)), 半径: 3.00
# Slice 69 - Region 1:
#   最大圆 - 圆心: (np.int64(110), np.int64(157)), 半径: 3.16
#   第二个圆 - 圆心: (np.int64(110), np.int64(157)), 半径: 3.16
#   第三个圆 - 圆心: (np.int64(110), np.int64(157)), 半径: 3.16
# Slice 69 - Region 2:
#   最大圆 - 圆心: (np.int64(116), np.int64(107)), 半径: 3.61
#   第二个圆 - 圆心: (np.int64(116), np.int64(107)), 半径: 3.61
#   第三个圆 - 圆心: (np.int64(116), np.int64(107)), 半径: 3.61
# Slice 69 - Region 3:
#   最大圆 - 圆心: (np.int64(201), np.int64(93)), 半径: 1.00
#   第二个圆 - 圆心: (np.int64(201), np.int64(93)), 半径: 1.00
#   第三个圆 - 圆心: (np.int64(201), np.int64(93)), 半径: 1.00
# Slice 69 - Region 4:
#   最大圆 - 圆心: (np.int64(234), np.int64(183)), 半径: 2.83
#   第二个圆 - 圆心: (np.int64(234), np.int64(183)), 半径: 2.83
#   第三个圆 - 圆心: (np.int64(234), np.int64(183)), 半径: 2.83
# Slice 70 - Region 1:
#   最大圆 - 圆心: (np.int64(110), np.int64(158)), 半径: 3.16
#   第二个圆 - 圆心: (np.int64(110), np.int64(158)), 半径: 3.16
#   第三个圆 - 圆心: (np.int64(110), np.int64(158)), 半径: 3.16
# Slice 70 - Region 2:
#   最大圆 - 圆心: (np.int64(119), np.int64(106)), 半径: 3.16
#   第二个圆 - 圆心: (np.int64(119), np.int64(106)), 半径: 3.16
#   第三个圆 - 圆心: (np.int64(119), np.int64(106)), 半径: 3.16
# Slice 70 - Region 3:
#   最大圆 - 圆心: (np.int64(203), np.int64(94)), 半径: 1.41
#   第二个圆 - 圆心: (np.int64(203), np.int64(94)), 半径: 1.41
#   第三个圆 - 圆心: (np.int64(203), np.int64(94)), 半径: 1.41
# Slice 70 - Region 4:
#   最大圆 - 圆心: (np.int64(235), np.int64(183)), 半径: 3.16
#   第二个圆 - 圆心: (np.int64(235), np.int64(183)), 半径: 3.16
#   第三个圆 - 圆心: (np.int64(235), np.int64(183)), 半径: 3.16
# Slice 71 - Region 1:
#   最大圆 - 圆心: (np.int64(110), np.int64(158)), 半径: 3.16
#   第二个圆 - 圆心: (np.int64(110), np.int64(158)), 半径: 3.16
#   第三个圆 - 圆心: (np.int64(110), np.int64(158)), 半径: 3.16
# Slice 71 - Region 2:
#   最大圆 - 圆心: (np.int64(120), np.int64(106)), 半径: 3.16
#   第二个圆 - 圆心: (np.int64(120), np.int64(106)), 半径: 3.16
#   第三个圆 - 圆心: (np.int64(120), np.int64(106)), 半径: 3.16
# Slice 71 - Region 3:
#   最大圆 - 圆心: (np.int64(201), np.int64(93)), 半径: 1.00
#   第二个圆 - 圆心: (np.int64(201), np.int64(93)), 半径: 1.00
#   第三个圆 - 圆心: (np.int64(201), np.int64(93)), 半径: 1.00
# Slice 71 - Region 4:
#   最大圆 - 圆心: (np.int64(235), np.int64(183)), 半径: 2.83
#   第二个圆 - 圆心: (np.int64(235), np.int64(183)), 半径: 2.83
#   第三个圆 - 圆心: (np.int64(235), np.int64(183)), 半径: 2.83
# Slice 72 - Region 1:
#   最大圆 - 圆心: (np.int64(109), np.int64(158)), 半径: 2.83
#   第二个圆 - 圆心: (np.int64(109), np.int64(158)), 半径: 2.83
#   第三个圆 - 圆心: (np.int64(109), np.int64(158)), 半径: 2.83
# Slice 72 - Region 2:
#   最大圆 - 圆心: (np.int64(119), np.int64(107)), 半径: 3.16
#   第二个圆 - 圆心: (np.int64(119), np.int64(107)), 半径: 3.16
#   第三个圆 - 圆心: (np.int64(119), np.int64(107)), 半径: 3.16
# Slice 72 - Region 3:
#   最大圆 - 圆心: (np.int64(201), np.int64(93)), 半径: 1.41
#   第二个圆 - 圆心: (np.int64(201), np.int64(93)), 半径: 1.41
#   第三个圆 - 圆心: (np.int64(201), np.int64(93)), 半径: 1.41
# Slice 72 - Region 4:
#   最大圆 - 圆心: (np.int64(235), np.int64(184)), 半径: 2.83
#   第二个圆 - 圆心: (np.int64(235), np.int64(184)), 半径: 2.83
#   第三个圆 - 圆心: (np.int64(235), np.int64(184)), 半径: 2.83
# Slice 73 - Region 1:
#   最大圆 - 圆心: (np.int64(109), np.int64(158)), 半径: 2.83
#   第二个圆 - 圆心: (np.int64(109), np.int64(158)), 半径: 2.83
#   第三个圆 - 圆心: (np.int64(109), np.int64(158)), 半径: 2.83
# Slice 73 - Region 2:
#   最大圆 - 圆心: (np.int64(121), np.int64(107)), 半径: 3.16
#   第二个圆 - 圆心: (np.int64(121), np.int64(107)), 半径: 3.16
#   第三个圆 - 圆心: (np.int64(121), np.int64(107)), 半径: 3.16
# Slice 73 - Region 3:
#   最大圆 - 圆心: (np.int64(201), np.int64(93)), 半径: 1.41
#   第二个圆 - 圆心: (np.int64(201), np.int64(93)), 半径: 1.41
#   第三个圆 - 圆心: (np.int64(201), np.int64(93)), 半径: 1.41
# Slice 73 - Region 4:
#   最大圆 - 圆心: (np.int64(236), np.int64(184)), 半径: 3.00
#   第二个圆 - 圆心: (np.int64(236), np.int64(184)), 半径: 3.00
#   第三个圆 - 圆心: (np.int64(236), np.int64(184)), 半径: 3.00
# Slice 74 - Region 1:
#   最大圆 - 圆心: (np.int64(109), np.int64(159)), 半径: 3.00
#   第二个圆 - 圆心: (np.int64(109), np.int64(159)), 半径: 3.00
#   第三个圆 - 圆心: (np.int64(109), np.int64(159)), 半径: 3.00
# Slice 74 - Region 2:
#   最大圆 - 圆心: (np.int64(120), np.int64(107)), 半径: 3.00
#   第二个圆 - 圆心: (np.int64(120), np.int64(107)), 半径: 3.00
#   第三个圆 - 圆心: (np.int64(120), np.int64(107)), 半径: 3.00
# Slice 74 - Region 3:
#   最大圆 - 圆心: (np.int64(203), np.int64(94)), 半径: 2.00
#   第二个圆 - 圆心: (np.int64(203), np.int64(94)), 半径: 2.00
#   第三个圆 - 圆心: (np.int64(203), np.int64(94)), 半径: 2.00
# Slice 74 - Region 4:
#   最大圆 - 圆心: (np.int64(236), np.int64(185)), 半径: 3.00
#   第二个圆 - 圆心: (np.int64(236), np.int64(185)), 半径: 3.00
#   第三个圆 - 圆心: (np.int64(236), np.int64(185)), 半径: 3.00
# Slice 75 - Region 1:
#   最大圆 - 圆心: (np.int64(109), np.int64(159)), 半径: 3.00
#   第二个圆 - 圆心: (np.int64(109), np.int64(159)), 半径: 3.00
#   第三个圆 - 圆心: (np.int64(109), np.int64(159)), 半径: 3.00
# Slice 75 - Region 2:
#   最大圆 - 圆心: (np.int64(121), np.int64(107)), 半径: 3.00
#   第二个圆 - 圆心: (np.int64(121), np.int64(107)), 半径: 3.00
#   第三个圆 - 圆心: (np.int64(121), np.int64(107)), 半径: 3.00
# Slice 75 - Region 3:
#   最大圆 - 圆心: (np.int64(202), np.int64(93)), 半径: 2.00
#   第二个圆 - 圆心: (np.int64(202), np.int64(93)), 半径: 2.00
#   第三个圆 - 圆心: (np.int64(202), np.int64(93)), 半径: 2.00
# Slice 75 - Region 4:
#   最大圆 - 圆心: (np.int64(236), np.int64(185)), 半径: 3.00
#   第二个圆 - 圆心: (np.int64(236), np.int64(185)), 半径: 3.00
#   第三个圆 - 圆心: (np.int64(236), np.int64(185)), 半径: 3.00
# Slice 76 - Region 1:
#   最大圆 - 圆心: (np.int64(109), np.int64(159)), 半径: 3.00
#   第二个圆 - 圆心: (np.int64(109), np.int64(159)), 半径: 3.00
#   第三个圆 - 圆心: (np.int64(109), np.int64(159)), 半径: 3.00
# Slice 76 - Region 2:
#   最大圆 - 圆心: (np.int64(122), np.int64(107)), 半径: 3.00
#   第二个圆 - 圆心: (np.int64(122), np.int64(107)), 半径: 3.00
#   第三个圆 - 圆心: (np.int64(122), np.int64(107)), 半径: 3.00
# Slice 76 - Region 3:
#   最大圆 - 圆心: (np.int64(201), np.int64(92)), 半径: 2.00
#   第二个圆 - 圆心: (np.int64(201), np.int64(92)), 半径: 2.00
#   第三个圆 - 圆心: (np.int64(201), np.int64(92)), 半径: 2.00
# Slice 76 - Region 4:
#   最大圆 - 圆心: (np.int64(237), np.int64(185)), 半径: 3.00
#   第二个圆 - 圆心: (np.int64(237), np.int64(185)), 半径: 3.00
#   第三个圆 - 圆心: (np.int64(237), np.int64(185)), 半径: 3.00
# Slice 77 - Region 1:
#   最大圆 - 圆心: (np.int64(109), np.int64(160)), 半径: 3.00
#   第二个圆 - 圆心: (np.int64(109), np.int64(160)), 半径: 3.00
#   第三个圆 - 圆心: (np.int64(109), np.int64(160)), 半径: 3.00
# Slice 77 - Region 2:
#   最大圆 - 圆心: (np.int64(122), np.int64(108)), 半径: 3.00
#   第二个圆 - 圆心: (np.int64(122), np.int64(108)), 半径: 3.00
#   第三个圆 - 圆心: (np.int64(122), np.int64(108)), 半径: 3.00
# Slice 77 - Region 3:
#   最大圆 - 圆心: (np.int64(202), np.int64(92)), 半径: 2.00
#   第二个圆 - 圆心: (np.int64(202), np.int64(92)), 半径: 2.00
#   第三个圆 - 圆心: (np.int64(202), np.int64(92)), 半径: 2.00
# Slice 77 - Region 4:
#   最大圆 - 圆心: (np.int64(237), np.int64(186)), 半径: 3.00
#   第二个圆 - 圆心: (np.int64(237), np.int64(186)), 半径: 3.00
#   第三个圆 - 圆心: (np.int64(237), np.int64(186)), 半径: 3.00
# Slice 78 - Region 1:
#   最大圆 - 圆心: (np.int64(109), np.int64(160)), 半径: 3.00
#   第二个圆 - 圆心: (np.int64(109), np.int64(160)), 半径: 3.00
#   第三个圆 - 圆心: (np.int64(109), np.int64(160)), 半径: 3.00
# Slice 78 - Region 2:
#   最大圆 - 圆心: (np.int64(121), np.int64(108)), 半径: 2.83
#   第二个圆 - 圆心: (np.int64(121), np.int64(108)), 半径: 2.83
#   第三个圆 - 圆心: (np.int64(121), np.int64(108)), 半径: 2.83
# Slice 78 - Region 3:
#   最大圆 - 圆心: (np.int64(202), np.int64(92)), 半径: 2.24
#   第二个圆 - 圆心: (np.int64(202), np.int64(92)), 半径: 2.24
#   第三个圆 - 圆心: (np.int64(202), np.int64(92)), 半径: 2.24
# Slice 78 - Region 4:
#   最大圆 - 圆心: (np.int64(237), np.int64(186)), 半径: 2.83
#   第二个圆 - 圆心: (np.int64(237), np.int64(186)), 半径: 2.83
#   第三个圆 - 圆心: (np.int64(237), np.int64(186)), 半径: 2.83
# Slice 79 - Region 1:
#   最大圆 - 圆心: (np.int64(109), np.int64(160)), 半径: 3.16
#   第二个圆 - 圆心: (np.int64(109), np.int64(160)), 半径: 3.16
#   第三个圆 - 圆心: (np.int64(109), np.int64(160)), 半径: 3.16
# Slice 79 - Region 2:
#   最大圆 - 圆心: (np.int64(121), np.int64(109)), 半径: 2.83
#   第二个圆 - 圆心: (np.int64(121), np.int64(109)), 半径: 2.83
#   第三个圆 - 圆心: (np.int64(121), np.int64(109)), 半径: 2.83
# Slice 79 - Region 3:
#   最大圆 - 圆心: (np.int64(202), np.int64(92)), 半径: 2.24
#   第二个圆 - 圆心: (np.int64(202), np.int64(92)), 半径: 2.24
#   第三个圆 - 圆心: (np.int64(202), np.int64(92)), 半径: 2.24
# Slice 79 - Region 4:
#   最大圆 - 圆心: (np.int64(237), np.int64(187)), 半径: 3.00
#   第二个圆 - 圆心: (np.int64(237), np.int64(187)), 半径: 3.00
#   第三个圆 - 圆心: (np.int64(237), np.int64(187)), 半径: 3.00
# Slice 80 - Region 1:
#   最大圆 - 圆心: (np.int64(108), np.int64(160)), 半径: 2.83
#   第二个圆 - 圆心: (np.int64(108), np.int64(160)), 半径: 2.83
#   第三个圆 - 圆心: (np.int64(108), np.int64(160)), 半径: 2.83
# Slice 80 - Region 2:
#   最大圆 - 圆心: (np.int64(121), np.int64(109)), 半径: 2.83
#   第二个圆 - 圆心: (np.int64(121), np.int64(109)), 半径: 2.83
#   第三个圆 - 圆心: (np.int64(121), np.int64(109)), 半径: 2.83
# Slice 80 - Region 3:
#   最大圆 - 圆心: (np.int64(202), np.int64(91)), 半径: 2.24
#   第二个圆 - 圆心: (np.int64(202), np.int64(91)), 半径: 2.24
#   第三个圆 - 圆心: (np.int64(202), np.int64(91)), 半径: 2.24
# Slice 80 - Region 4:
#   最大圆 - 圆心: (np.int64(238), np.int64(187)), 半径: 3.16
#   第二个圆 - 圆心: (np.int64(238), np.int64(187)), 半径: 3.16
#   第三个圆 - 圆心: (np.int64(238), np.int64(187)), 半径: 3.16
# Slice 81 - Region 1:
#   最大圆 - 圆心: (np.int64(108), np.int64(160)), 半径: 2.83
#   第二个圆 - 圆心: (np.int64(108), np.int64(160)), 半径: 2.83
#   第三个圆 - 圆心: (np.int64(108), np.int64(160)), 半径: 2.83
# Slice 81 - Region 2:
#   最大圆 - 圆心: (np.int64(122), np.int64(108)), 半径: 2.83
#   第二个圆 - 圆心: (np.int64(122), np.int64(108)), 半径: 2.83
#   第三个圆 - 圆心: (np.int64(122), np.int64(108)), 半径: 2.83
# Slice 81 - Region 3:
#   最大圆 - 圆心: (np.int64(202), np.int64(91)), 半径: 2.83
#   第二个圆 - 圆心: (np.int64(202), np.int64(91)), 半径: 2.83
#   第三个圆 - 圆心: (np.int64(202), np.int64(91)), 半径: 2.83
# Slice 81 - Region 4:
#   最大圆 - 圆心: (np.int64(238), np.int64(188)), 半径: 3.00
#   第二个圆 - 圆心: (np.int64(238), np.int64(188)), 半径: 3.00
#   第三个圆 - 圆心: (np.int64(238), np.int64(188)), 半径: 3.00
# Slice 82 - Region 1:
#   最大圆 - 圆心: (np.int64(108), np.int64(161)), 半径: 2.83
#   第二个圆 - 圆心: (np.int64(108), np.int64(161)), 半径: 2.83
#   第三个圆 - 圆心: (np.int64(108), np.int64(161)), 半径: 2.83
# Slice 82 - Region 2:
#   最大圆 - 圆心: (np.int64(122), np.int64(108)), 半径: 2.24
#   第二个圆 - 圆心: (np.int64(122), np.int64(108)), 半径: 2.24
#   第三个圆 - 圆心: (np.int64(122), np.int64(108)), 半径: 2.24
# Slice 82 - Region 3:
#   最大圆 - 圆心: (np.int64(202), np.int64(91)), 半径: 2.83
#   第二个圆 - 圆心: (np.int64(202), np.int64(91)), 半径: 2.83
#   第三个圆 - 圆心: (np.int64(202), np.int64(91)), 半径: 2.83
# Slice 82 - Region 4:
#   最大圆 - 圆心: (np.int64(238), np.int64(188)), 半径: 2.83
#   第二个圆 - 圆心: (np.int64(238), np.int64(188)), 半径: 2.83
#   第三个圆 - 圆心: (np.int64(238), np.int64(188)), 半径: 2.83
# Slice 83 - Region 1:
#   最大圆 - 圆心: (np.int64(109), np.int64(161)), 半径: 3.16
#   第二个圆 - 圆心: (np.int64(109), np.int64(161)), 半径: 3.16
#   第三个圆 - 圆心: (np.int64(109), np.int64(161)), 半径: 3.16
# Slice 83 - Region 2:
#   最大圆 - 圆心: (np.int64(122), np.int64(108)), 半径: 2.24
#   第二个圆 - 圆心: (np.int64(122), np.int64(108)), 半径: 2.24
#   第三个圆 - 圆心: (np.int64(122), np.int64(108)), 半径: 2.24
# Slice 83 - Region 3:
#   最大圆 - 圆心: (np.int64(202), np.int64(90)), 半径: 2.83
#   第二个圆 - 圆心: (np.int64(202), np.int64(90)), 半径: 2.83
#   第三个圆 - 圆心: (np.int64(202), np.int64(90)), 半径: 2.83
# Slice 83 - Region 4:
#   最大圆 - 圆心: (np.int64(238), np.int64(189)), 半径: 3.00
#   第二个圆 - 圆心: (np.int64(238), np.int64(189)), 半径: 3.00
#   第三个圆 - 圆心: (np.int64(238), np.int64(189)), 半径: 3.00
# Slice 84 - Region 1:
#   最大圆 - 圆心: (np.int64(109), np.int64(161)), 半径: 3.00
#   第二个圆 - 圆心: (np.int64(109), np.int64(161)), 半径: 3.00
#   第三个圆 - 圆心: (np.int64(109), np.int64(161)), 半径: 3.00
# Slice 84 - Region 2:
#   最大圆 - 圆心: (np.int64(122), np.int64(109)), 半径: 2.24
#   第二个圆 - 圆心: (np.int64(122), np.int64(109)), 半径: 2.24
#   第三个圆 - 圆心: (np.int64(122), np.int64(109)), 半径: 2.24
# Slice 84 - Region 3:
#   最大圆 - 圆心: (np.int64(203), np.int64(90)), 半径: 2.83
#   第二个圆 - 圆心: (np.int64(203), np.int64(90)), 半径: 2.83
#   第三个圆 - 圆心: (np.int64(203), np.int64(90)), 半径: 2.83
# Slice 84 - Region 4:
#   最大圆 - 圆心: (np.int64(239), np.int64(189)), 半径: 3.16
#   第二个圆 - 圆心: (np.int64(239), np.int64(189)), 半径: 3.16
#   第三个圆 - 圆心: (np.int64(239), np.int64(189)), 半径: 3.16
# Slice 85 - Region 1:
#   最大圆 - 圆心: (np.int64(109), np.int64(161)), 半径: 2.83
#   第二个圆 - 圆心: (np.int64(109), np.int64(161)), 半径: 2.83
#   第三个圆 - 圆心: (np.int64(109), np.int64(161)), 半径: 2.83
# Slice 85 - Region 2:
#   最大圆 - 圆心: (np.int64(123), np.int64(108)), 半径: 2.24
#   第二个圆 - 圆心: (np.int64(123), np.int64(108)), 半径: 2.24
#   第三个圆 - 圆心: (np.int64(123), np.int64(108)), 半径: 2.24
# Slice 85 - Region 3:
#   最大圆 - 圆心: (np.int64(203), np.int64(90)), 半径: 2.83
#   第二个圆 - 圆心: (np.int64(203), np.int64(90)), 半径: 2.83
#   第三个圆 - 圆心: (np.int64(203), np.int64(90)), 半径: 2.83
# Slice 85 - Region 4:
#   最大圆 - 圆心: (np.int64(239), np.int64(189)), 半径: 2.83
#   第二个圆 - 圆心: (np.int64(239), np.int64(189)), 半径: 2.83
#   第三个圆 - 圆心: (np.int64(239), np.int64(189)), 半径: 2.83
# Slice 86 - Region 1:
#   最大圆 - 圆心: (np.int64(109), np.int64(162)), 半径: 3.00
#   第二个圆 - 圆心: (np.int64(109), np.int64(162)), 半径: 3.00
#   第三个圆 - 圆心: (np.int64(109), np.int64(162)), 半径: 3.00
# Slice 86 - Region 2:
#   最大圆 - 圆心: (np.int64(123), np.int64(108)), 半径: 2.24
#   第二个圆 - 圆心: (np.int64(123), np.int64(108)), 半径: 2.24
#   第三个圆 - 圆心: (np.int64(123), np.int64(108)), 半径: 2.24
# Slice 86 - Region 3:
#   最大圆 - 圆心: (np.int64(203), np.int64(90)), 半径: 2.83
#   第二个圆 - 圆心: (np.int64(203), np.int64(90)), 半径: 2.83
#   第三个圆 - 圆心: (np.int64(203), np.int64(90)), 半径: 2.83
# Slice 86 - Region 4:
#   最大圆 - 圆心: (np.int64(240), np.int64(189)), 半径: 3.00
#   第二个圆 - 圆心: (np.int64(240), np.int64(189)), 半径: 3.00
#   第三个圆 - 圆心: (np.int64(240), np.int64(189)), 半径: 3.00
# Slice 87 - Region 1:
#   最大圆 - 圆心: (np.int64(108), np.int64(163)), 半径: 2.83
#   第二个圆 - 圆心: (np.int64(108), np.int64(163)), 半径: 2.83
#   第三个圆 - 圆心: (np.int64(108), np.int64(163)), 半径: 2.83
# Slice 87 - Region 2:
#   最大圆 - 圆心: (np.int64(123), np.int64(108)), 半径: 2.24
#   第二个圆 - 圆心: (np.int64(123), np.int64(108)), 半径: 2.24
#   第三个圆 - 圆心: (np.int64(123), np.int64(108)), 半径: 2.24
# Slice 87 - Region 3:
#   最大圆 - 圆心: (np.int64(204), np.int64(91)), 半径: 2.83
#   第二个圆 - 圆心: (np.int64(204), np.int64(91)), 半径: 2.83
#   第三个圆 - 圆心: (np.int64(204), np.int64(91)), 半径: 2.83
# Slice 87 - Region 4:
#   最大圆 - 圆心: (np.int64(240), np.int64(190)), 半径: 3.00
#   第二个圆 - 圆心: (np.int64(240), np.int64(190)), 半径: 3.00
#   第三个圆 - 圆心: (np.int64(240), np.int64(190)), 半径: 3.00
# Slice 88 - Region 1:
#   最大圆 - 圆心: (np.int64(108), np.int64(163)), 半径: 2.83
#   第二个圆 - 圆心: (np.int64(108), np.int64(163)), 半径: 2.83
#   第三个圆 - 圆心: (np.int64(108), np.int64(163)), 半径: 2.83
# Slice 88 - Region 2:
#   最大圆 - 圆心: (np.int64(123), np.int64(108)), 半径: 2.24
#   第二个圆 - 圆心: (np.int64(123), np.int64(108)), 半径: 2.24
#   第三个圆 - 圆心: (np.int64(123), np.int64(108)), 半径: 2.24
# Slice 88 - Region 3:
#   最大圆 - 圆心: (np.int64(204), np.int64(90)), 半径: 2.83
#   第二个圆 - 圆心: (np.int64(204), np.int64(90)), 半径: 2.83
#   第三个圆 - 圆心: (np.int64(204), np.int64(90)), 半径: 2.83
# Slice 88 - Region 4:
#   最大圆 - 圆心: (np.int64(240), np.int64(190)), 半径: 2.83
#   第二个圆 - 圆心: (np.int64(240), np.int64(190)), 半径: 2.83
#   第三个圆 - 圆心: (np.int64(240), np.int64(190)), 半径: 2.83
# ...
#   Layer 60: Point (111.19586421932891, 154.4137705061587)
#   Layer 61: Point (111.16993804477575, 154.70481209960514)
#   Layer 62: Point (111.13839504475519, 155.0012417910876)
#   Layer 277: Point (96.41749227501678, 184.68743267203337)
#   Layer 278: Point (96.52877334356262, 184.693134744931)
#   Layer 279: Point (96.64210459259212, 184.6955973384016)
#   Layer 280: Point (96.7574852903538, 184.69468591038415)
#   Layer 281: Point (96.87491470509623, 184.69026591881772)
#   Layer 282: Point (96.99439210506789, 184.68220282164137)
#   Layer 283: Point (97.11591675851733, 184.67036207679425)
#   Layer 284: Point (97.23948793369304, 184.65460914221538)
#   Layer 285: Point (97.36510489884358, 184.63480947584378)
#   Layer 286: Point (97.49276692221748, 184.61082853561854)
#   Layer 287: Point (97.62247327206322, 184.58253177947876)
#   Layer 288: Point (97.75422321662937, 184.5497846653635)
#   Layer 289: Point (97.88801602416439, 184.51245265121173)
#   Layer 290: Point (98.02385096291685, 184.47040119496268)
#   Layer 291: Point (98.16172730113529, 184.42349575455532)
#   Layer 292: Point (98.30164430706819, 184.3716017879287)
#   Layer 293: Point (98.44360124896411, 184.31458475302193)
#   Layer 294: Point (98.58759739507153, 184.25231010777404)
#   Layer 295: Point (98.73363201363901, 184.1846433101241)
#   Layer 296: Point (98.88170437291507, 184.11144981801124)
#   Layer 297: Point (99.0318137411482, 184.03259508937444)
#   Layer 298: Point (99.18395938658695, 183.94794458215281)
#   Layer 299: Point (99.33814057747985, 183.85736375428544)
#   Layer 300: Point (99.4943565820754, 183.76071806371135)
#   Layer 301: Point (99.65260666862216, 183.65787296836962)
#   Layer 302: Point (99.81289010536861, 183.5486939261993)
#   Layer 303: Point (99.9752061605633, 183.43304639513948)
#   Layer 304: Point (100.13955410245474, 183.31079583312925)
#   Layer 305: Point (100.30593319929147, 183.1818076981076)
#   Layer 306: Point (100.474342719322, 183.04594744801366)
#   Layer 307: Point (100.64478193079485, 182.90308054078645)
#   Layer 308: Point (100.81725010195855, 182.7530724343651)
#   Layer 309: Point (100.99174650106163, 182.59578858668866)
#   Layer 310: Point (101.16827039635258, 182.43109445569613)
#   Layer 311: Point (101.34682105607997, 182.25885549932664)
#   Layer 312: Point (101.52739774849229, 182.07893717551923)
#   Layer 313: Point (101.70999974183809, 181.89120494221297)
#   Layer 314: Point (101.89462630436589, 181.69552425734696)
#   Layer 315: Point (102.08127670432417, 181.4917605788602)
#   Layer 316: Point (102.2699502099615, 181.27977936469182)
#   Layer 317: Point (102.46064608952636, 181.05944607278084)
#   Layer 318: Point (102.65336361126732, 180.8306261610663)
#   Layer 319: Point (102.84810204343289, 180.5931850874874)
#   Layer 320: Point (103.04486065427156, 180.34698830998306)
#   Layer 321: Point (103.24363871203191, 180.0919012864924)
# /var/folders/vh/pjl542w16gz9d4ftq8k0gxmh0000gn/T/ipykernel_67631/1696304141.py:100: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed in 3.11. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap()`` or ``pyplot.get_cmap()`` instead.
#   cmap = cm.get_cmap(colormap_name)
# 生成三维表面网格
# 三维表面网格生成完毕.
# 生成中心线的三维表面网格
# 中心线的三维表面网格生成完毕.
# 可视化三维模型和中心线
# 2024-10-22 19:36:17.899 python[67631:9000071] +[IMKClient subclass]: chose IMKClient_Legacy
# 2024-10-22 19:36:17.899 python[67631:9000071] +[IMKInputSession subclass]: chose IMKInputSession_Legacy
